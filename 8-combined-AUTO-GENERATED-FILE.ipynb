# %% [markdown]
# ### DO NOT EDIT: This file was generated by a script that combines all .ipynb files in the current directory.

# %% [markdown]
# ## Table of Contents
# <a id='top-of-page'></a>
#
# - [1-workspace_setup](#1-workspace_setup)
# - [2-load_raw_db](#2-load_raw_db)
# - [3-county_and_dist_tables](#3-county_and_dist_tables)
# - [4-county_demographics](#4-county_demographics)
# - [5-education](#5-education)
# - [6-crime](#6-crime)
# - [7-prepare_for_dashboard](#7-prepare_for_dashboard)

# %% [markdown]
# ---
# ---
# # `1-workspace_setup`
#
# [BACK TO TOP ^](#top-of-page)
#
# ---
# ---

# %% [markdown]
# # Setup
#
# ### Table of Contents
# 1. [SQL Interface](#sql-interface)
# 2. [Helper Methods](#helper-methods)
# 2. [Pandas, extended inplace](#pandas-extended-inplace)
# 2. [Format District](#format-district)
# 2. [GeoDF](#geodf)
# 2. [GroupedDF](#groupeddf)

# %%
# pip install numpy pandas

# %% [markdown]
# #### `extend-inplace` - a simple library I built, inspired by this project.
# - Docs & source here: [github.com/ryayoung/extend-inplace](https://github.com/ryayoung/extend-inplace)

# %%
# pip install extend-inplace

# %%
from typing import Iterable, Any
import pandas as pd
import numpy as np
import sqlite3 as sqlite
import re
from extend_inplace import Extend

# %% [markdown]
# ## SQL Interface
#
# - End-user will use `read_raw()`, `read_main()`, `write_raw()`, and `write_main()` to communicate with sqlite

# %%
get_con_raw = lambda: sqlite.connect("data_raw.db")
get_con_main = lambda: sqlite.connect("data_main.db")
sql = dict(
    raw = dict(con = get_con_raw, cache = dict()),
    main = dict(con = get_con_main, cache = dict()),
)

# %% [markdown]
# Helper methods for the end-user methods

# %%
def _to_sql(
    df: pd.DataFrame,
    name: str,
    con: str
) -> None | int:
    """
    Save/replace `df` under `name` in sqlite. Database depends on `con`
    """
    res = df.to_sql(name, con=sql[con]['con'](), index=False, if_exists='replace')
    return res


def _format_query(
    *args: tuple[str], # only one string arg processed
    **kwargs: dict[str, str],
) -> str:
    """
    Allow for more pythonic style of writing sql queries, for better
    readability, user experience, and user-error prevention. Underscores
    can be used to prefix/suffix python reserved word kwargs like FROM, IF, etc.
    --
    >>> _format_query("SELECT name, age FROM my_table")
    SELECT name, age FROM my_table
    >>> _format_query("my_table")
    SELECT * FROM my_table
    >>> _format_query("my_table", WHERE = "something = something")
    SELECT * FROM my_table WHERE something = something
    >>> _format_query("name, age", from_ = "my_table")
    SELECT name, age FROM my_table
    """
    kwarg_query = " ".join([f'{k.strip("_").upper()} {v}' for k,v in kwargs.items()])
    if len(args) == 1:
        if len(args[0]) == len(re.sub(r"\s+", "", args[0])):
            query = f"SELECT * FROM {args[0]} "
        elif "select" not in args[0].lower():
            query = f"SELECT {args[0]} "
        else:
            query = args[0] + " "
        return query + kwarg_query
    else:
        return kwarg_query


def _read_sql(
    *args: tuple[str, ...],
    con: str,
    **kwargs: dict[str, str],
) -> pd.DataFrame:
    """
    This method is specific to this script. It references global variables and funcs
    """
    query = _format_query(*args, **kwargs)

    if (cached := sql[con]['cache'].get(query, None)) is not None:
        return cached.copy()

    df = sql[con]['cache'][query] = pd.read_sql(query, con=sql[con]['con']())
    return df

# %% [markdown]
# End-user will use these read/write methods to communicate with sqlite

# %%
read_raw = lambda *args, **kwargs: _read_sql(*args, **kwargs, con='raw')
read_main = lambda *args, **kwargs: _read_sql(*args, **kwargs, con='main')
# def write_raw(*args, **kwargs):
    # _to_sql(*args, **kwargs, con='raw')
write_raw = lambda *args, **kwargs: _to_sql(*args, **kwargs, con='raw')
write_main = lambda *args, **kwargs: _to_sql(*args, **kwargs, con='main')

# %% [markdown]
# ## Helper methods

# %%
def head(
    *dfs: tuple[pd.DataFrame, ...],
    n: int = 3,
    with_tail: bool = False
) -> None:
    '''
    Like display() and pd.DataFrame.head got married and had a kid.
    - `with_tail` will concat head and tail together.
    '''
    for df in dfs:
        print(f'{df.shape[1]} cols x {df.shape[0]} rows')
        if with_tail:
            display(pd.concat([df.head(n-1), df.tail(n-1)], axis=0))
        else:
            display(df.head(3))


def _flatten_iterable(
    args: Any
) -> tuple[Any, ...]:
    """
    Turns anything into a flattened tuple of non-iterable (str, bytes excluded) values

    >>> _flatten_iterable(int)
    (<class 'int'>,)
    >>> _flatten_iterable(['hi'])
    ('hi',)
    >>> _flatten_iterable(['hi', (1,3, [8]), [((3,3,3))]])
    ('hi', 1, 3, 8, 3, 3, 3)
    """

    def valid_iterable(e: Any) -> bool:
        if isinstance(e, Iterable) and not isinstance(e, (str, bytes)):
            return True
        return False

    def flatten(elems: Iterable[Any]):
        for e in elems:
            if valid_iterable(e):
                yield from flatten(e)
            else:
                yield e

    args = args if valid_iterable(args) else (args,)

    return tuple(flatten(args))

# %% [markdown]
# ## Pandas, extended inplace
# - Modifying pandas `DataFrame` and `Series` classes in-place with the following extra instance methods

# %%
@Extend(pd.Series)
def rename_vals_from_df(self, changes:pd.DataFrame) -> pd.Series:
    cols = changes.columns
    old, new = changes[cols[0]], changes[cols[1]]
    return self.map(dict(zip(old, new)))

# %%
@Extend(pd.DataFrame)
class _:
    def set_columns(self, *new) -> pd.DataFrame:
        new = _flatten_iterable(new)
        self.columns = new
        return self


    def rename_col(self, old:str, new:str) -> pd.DataFrame:
        """
        Simplify syntax for renaming one column
        """
        return self.rename(columns={old:new})


    def drop_cols(self, *columns) -> pd.DataFrame:
        """
        Simplify syntax of dropping columns
        """
        cols = _flatten_iterable(columns)
        cols = [c for c in cols if c in self.columns]
        return self.drop(columns=cols)


    def prefix_cols(self, cols:str or list, prefix:str) -> pd.DataFrame:
        """
        Like df.add_prefix(), but takes a subset of columns as first positional
        """
        if isinstance(cols, str):
            cols = [cols]
        return self.rename(columns={col: f'{prefix}{col}' for col in cols})


    def reset_multilevel_columns(
        self,
        *new_columns: tuple[str | Iterable[str], ...],
    ) -> pd.DataFrame:
        """
        Use this after df.pivot() to flatten and rename columns.
        """
        new_columns = _flatten_iterable(new_columns)
        self = self.reset_index()
        self.columns = self.columns.droplevel()
        self.columns.name = None
        self = self.set_columns(new_columns)
        return self


    def col_replace(
        self,
        text: str | dict,
        replacement: str | None = None
    ) -> pd.DataFrame:
        """
        Replace a pattern in each column NAME
        """
        if replacement is None:
            if isinstance(text, dict):
                to_replace = text
            else:
                raise ValueError("Multiple values must be passed as dict")
        else:
            to_replace = {text: replacement}
        
        for old, new in to_replace.items():
            for c in self.columns:
                if c != old:
                    self = self.rename(columns={c: c.replace(old, new)})
        return self


    def coerce_type(
        self,
        dtype: str or type,
        subset: list = None,
        exclude: list = None
    ) -> pd.DataFrame:
        """
        Iteratively try to set all columns to type
        """
        df = self.copy()
        cols = tuple(subset) if subset else tuple(self.columns)
        if exclude:
            cols = [c for c in cols if c not in exclude]
        for c in cols:
            try:
                df[c] = df[c].astype(dtype)
            except Exception:
                pass
        return df


    def insert_at(
        self,
        target: str | int,
        name: str,
        col: pd.Series
    ) -> pd.DataFrame:
        """
        Insert col before target col name, or to index.
        Like df.insert(), but takes a column name as location, instead of int """
        df = self.copy()
        if isinstance(target, int):
            idx = target
        else:
            idx = list(df.columns).index(target)
        df.insert(idx, name, col)
        return df


    def move_col(
        self,
        name: str,
        target: str | int
    ) -> pd.DataFrame:
        """
        Move col to before target col name, or to index.
        - Must not mutate original dataframe (so we can chain the func
        and re-run cells).
        - Placement must be correct: if target column is string, always
        place our column before the target column. If target is an index,
        the RESULTING dataframe must have our new column in the specified index.
        """
        cols = list(self.columns)

        if isinstance(target, int):
            idx = target
            cols.remove(name)
            cols.insert(idx, name)
        elif isinstance(target, str):
            idx = list(self.columns).index(target)
            cols[cols.index(name)] = "7dwIFmVgq5f1z"
            cols.insert(idx, name)
            cols.remove("7dwIFmVgq5f1z")

        return self[cols]


    def separate_by(
        self,
        to_match: list or str,
        index: list = [],
        keep: list = [],
        start: bool = False,
        end: bool = False,
        mode: str = "include",
    ) -> pd.DataFrame:
        """
        Given a df and a substring, filter for columns whose name does, or
        does not, contain a substring

        to_match
            text(s) to match
        index
            key columns to ignore (year, county, district, etc.)
        keep
            columns to ignore in matching. If "exclude", these columns will be removed
        start
            match only if column starts with `to_match` element, instead of contains
        end
            match only if column ends with `to_match` element, instead of contains
        mode
            If "include", returned df will include columns in `index`, `keep`, and matches
            If "exclude", returned df will exclude columns in `keep`, and matches
        """
        if not isinstance(to_match, list):
            to_match = [to_match]

        names = [item for sublist in [[c for c in self.columns if (
                c.startswith(txt) if start else c.endswith(txt) if end else txt in c
            )] for txt in to_match] for item in sublist]

        if mode == 'include':
            return self.copy()[index + keep + names]
        if mode == 'exclude':
            return self.copy().drop(columns = keep + names)


    def display(self, text: bool = None, head: bool = True) -> pd.DataFrame:
        """
        Display while chaining methods. Return self
        """
        if text is not None:
            print(text)
        to_display = self.head(3) if head else self
        display(to_display)
        return self
    

    def rename_vals_from_df(self, column: str, changes: pd.DataFrame) -> pd.DataFrame:
        """
        Renames values in a column using a 2-column dataframe (old, new)
        instead of dictionary.
        """
        df = self.copy()
        df[column] = df[column].rename_vals_from_df(changes)
        return df


    def rename_cols_from_df(self, changes: pd.DataFrame) -> pd.DataFrame:
        """
        Renames columns in df, mapping changes from a 2-column df (old, new)
        """
        cols = changes.columns
        old, new = changes[cols[0]], changes[cols[1]]
        return self.rename(columns=dict(zip(old, new)))

# %% [markdown]
# ## Format District
# - Apply the below function to all school district columns from source, to standardize their naming conventions to allow joins

# %%
def standardize_district_name(name: str) -> str:
    """
    Apply this iteratively (with pd.Series.apply())
    to school district name columns to standardize their naming conventions
    as best as possible prior to merging datasets with potentially
    very different naming conventions.
    """
    import re
    name = name.upper()
    name = re.sub('S/D', '', name)
    name = re.sub('-|\.|\(|\)|/|:', '', name)
    name = re.sub(' CONSOLIDATED', '', name)
    name = re.sub('\s?SCHOOL DISTRICT', '', name)
    
    # Number patterns
    name = re.sub(r' RENO\s?(\d+)', r'\1', name)
    name = re.sub(r' NO\s?(\d+)', r'\1', name)
    name = re.sub(r' RD\s?(\d+)', r'\1', name)
    name = re.sub(r' RJ\s?(\d+)', r'\1', name)
    name = re.sub(r' RE\s?(\d+)J?T?', r'\1', name)
    name = re.sub(r' R\s?(\d+)J?', r'\1', name)
    name = re.sub(r' C\s?(\d+)', r'\1', name)

    # Remove spaces
    name = re.sub('\s', '', name)

    # Number patterns (text at end)
    name = re.sub(r'(\d+)R', r'\1', name)
    name = re.sub(r'(\d+)J', r'\1', name)
    name = re.sub(r'(\d+)JT', r'\1', name)

    # Delete text parts
    name = re.sub('RURAL', '', name)
    name = re.sub('SCHOOLS', '', name)
    # name = re.sub('SCHOOLDISTRICT', '', name)
    name = re.sub('SCHOOLDIST', '', name)
    name = re.sub('WATERSHED', '', name)
    name = name.strip()

    # Replace full
    name = name.replace(r'GILCREST', 'WELDCOUNTY')
    name = name.replace(r'FLORENCE', 'FREMONT')
    name = name.replace(r'CONSOLIDATED1', 'CUSTERCOUNTY1')
    name = re.sub(r'(PUEBLOCITY)(\d+)', r'\1', name)
    name = re.sub(r'^CREEDE$', r'CREEDE1', name)

    name = name.strip()
    # Push number out
    name = re.sub(r'(.*?)(\d+)(.*)', r'\1\3 \2', name)
    return name


def join_conflicts(
    df1: pd.DataFrame,
    df2: pd.DataFrame,
    col: str
) -> pd.DataFrame:
    '''
    Use when trying to join columns and see values that aren't shared.
    There's DEFINITELY a better way to do this. But I'm lazy, and nobody cares!
    '''
    import pandas as pd

    col_items1 = sorted(df1[col])
    col_items2 = sorted(df2[col])

    items1_diff = [i for i in col_items1 if i not in col_items2]
    items2_diff = [i for i in col_items2 if i not in col_items1]

    # Make lists same length.
    if len(items1_diff) > len(items2_diff):
        items2_diff += [None] * (len(items1_diff) - len(items2_diff))
    elif len(items2_diff) > len(items1_diff):
        items1_diff += [None] * (len(items2_diff) - len(items1_diff))
    
    return pd.DataFrame(list(zip(items1_diff, items2_diff)))

# %% [markdown]
# ## GeoDF
#
# - Child class of `geopy.GeoDataFrame` to provide ease of use and additional functionality

# %%
import geopandas as gp
from shapely import wkt

class GeoDF(gp.GeoDataFrame):

    def __init__(self, df, geo=None, crs='epsg:4326'):
        if type(df) == str:
            df = pd.read_csv(df)
        if type(df) == pd.DataFrame:
            df = df.copy()

            cols = [c for c in df.columns if c.startswith('geo_')]
            for c in cols:
                df[c] = df[c].fillna('GEOMETRYCOLLECTION EMPTY')
                df[c] = gp.GeoSeries(df[c].apply(wkt.loads))

            if not geo:
                geo = cols[0]

            df['geometry'] = df[geo]

        super(GeoDF, self).__init__(df, crs=crs)
    

    def explore(self, tooltip=None, geo=None, **kwargs):
        if geo:
            self.set_geo(geo)
        
        if not tooltip:
            tooltip = self.columns[0]
            if 'county' in self.columns and 'dist' in self.columns:
                tooltip = ['county', 'dist']

        return super().loc[self['geometry'].astype(str) != 'GEOMETRYCOLLECTION EMPTY'].explore(tooltip=tooltip, **kwargs)


    def df(self):
        return self[self.geometry.astype(str) != 'GEOMETRYCOLLECTION EMPTY']


    def set_geo(self, geo, crs='epsg:4326'):
        self['geometry'] = self[geo]
    

    def copy(self):
        return GeoDF(super().copy())

# %% [markdown]
# ## GroupedDF
#
# - Lets us split a dataframe into organized groups based on column names.
# - Useful for massive dataframes with too many columns to conveniently select columns manually

# %%
from copy import deepcopy

class GroupedDF:
    default_index = []
    groups: dict = None

    def __init__(self, df, index=[], custom={}, show_g_names=True):
        self.index = index
        if self.index == []: self.index = GroupedDF.default_index

        self.index = index
        self._df = deepcopy(df)
        self._show_g_names = show_g_names

        self._custom = custom
        self.refresh_groups()
    

    def refresh_groups(self):
        self._dict = {g: self._df.separate_by(g, self.index, start=True, mode='include') for g in GroupedDF.groups.keys()}

        if self._show_g_names == False:
            for k, v in self._dict.items():
                self._dict[k] = v.col_replace(f'{k}_', '')

        for name, cols in self._custom.items():
            self._dict[name] = self._df[cols]

        for k, v in self._dict.items():
            setattr(self, k, v)
    

    @classmethod
    def set_groups(cls, items: dict or list):

        if type(items) == list:
            cls.groups = {k: "" for k in items}
            return
        
        cls.groups = items


    @property
    def df(self):
        return self._df
    
    @df.setter
    def df(self, new):
        self._df = new
        self.refresh_groups()


    def __getattr__(self, name):
        return self._dict.get(name)

    def __getitem__(self, name):
        return self._dict[name]
    

    @property
    def dict(self):
        return self._dict
    
    @property
    def show_g_names(self):
        return self._show_g_names
    
    @show_g_names.setter
    def show_g_names(self, val:bool):
        self._show_g_names = val
        self.refresh_groups()
    

    def display(self, rows=3, exclude=[]):
        for k, v in self._dict.items():
            print(k, GroupedDF.groups[k], sep=': ')
            display(v.drop(columns=exclude).head(rows))
            print()

# %% [markdown]
# ---
# ---
# # `2-load_raw_db`
#
# [BACK TO TOP ^](#top-of-page)
#
# ---
# ---

# %% [markdown]
# # Load data into sqlite
# ---
# #### Note: by default, this will pull data directly from the source. Source dataset formatting can change at any time. If you encounter errors elsewhere in this pipeline, use backup data instead by setting `use_backup=True` below
# (edit: `use_backup` defaults to True)
#
# - With the Socrata ID and desired key name for all datasets:
#   - Format a request url with the ID
#   - Use `pd.read_csv()` to download the dataset into a dataframe.
#   - Insert the table into sql, using dictionary key as table name

# %%
use_backup = True

# %%
dataset_info = {
    'districts': 'mm2p-ag5w',
    'counties': 'ahgn-r8s5',
    'census_counties_2012': 'f4n4-vnyx',
    'census_counties_2013': 'm3j7-raj9',
    'census_counties_2014': 'wshk-29g7',
    'census_counties_2015': 't48m-528x',
    'census_counties_2016': 'eghh-ua8y',
    'census_counties_2017': 'ewkj-ipn7',
    'census_counties_2018': 'xum2-smvh',
    'census_counties_2019': '8j3i-rjn4',
    'census_counties_field_desc': 'qten-sdpn',
    'county_population': 'eeah-cmy8',
    'crime_16_19': 'j6g4-gayk',
    'crime_97_15': '6vnq-az4b',
    'dist_grad_rate': 'cfyh-6xxg',
    'dist_mobility_demographics': 'rg84-k4d3',
    'dist_student_mobility': '6wcd-ysh5',
}

# %%
format_url = lambda id: f'https://data.colorado.gov/api/views/{id}/rows.csv?accessType=DOWNLOAD'
backup_file_fmt = lambda name: f"backup/{name}.parquet.gzip"


def query(txt: str, con: str) -> list:
    cur = sql[con]['con']().cursor()
    return cur.execute(txt).fetchall()


def table_exists(con: str, name):
    c = sql[con]['con']().cursor()
                
    # get the count of tables with the name
    c.execute(f"""
    SELECT
        count(name)
    FROM sqlite_master
    WHERE type='table'
        AND name='{name}'
    """)

    # if the count is 1, then table exists
    if c.fetchone()[0] == 1:
        return True
    return False

# %% [markdown]
# ## Load tables and write to raw

# %%
for name, id in dataset_info.items():
    if table_exists('raw', name):
        continue
    if use_backup == True:
        df = pd.read_parquet(backup_file_fmt(name))
    else:
        df = pd.read_csv(format_url(id))
    write_raw(df, name)

# %% [markdown]
# ## See tables in raw and main

# %%
raw_tables = query('''SELECT name FROM sqlite_master WHERE type='table';''', con='raw')
main_tables = query('''SELECT name FROM sqlite_master WHERE type='table';''', con='main')

print("RAW:")
print(*[t[0] for t in raw_tables], sep='\n')
print("\nMAIN:")
print(*[t[0] for t in main_tables], sep='\n')
# Out:
# RAW:
# districts
# counties
# census_counties_2012
# census_counties_2013
# census_counties_2014
# census_counties_2015
# census_counties_2016
# census_counties_2017
# census_counties_2018
# census_counties_2019
# census_counties_field_desc
# county_population
# crime_16_19
# crime_97_15
# dist_grad_rate
# dist_mobility_demographics
# dist_student_mobility
#
# MAIN:

# %% [markdown]
# ### Save to backup?

# %%
def save_raw_data_to_backup():
    """
    No need to use this unless you want to backup current
    state of raw datasets as parquet files
    """
    for name in dataset_info.keys():
        df = read_raw(name)
        df.to_parquet(backup_file_fmt(name), compression='gzip', index=False)

# save_raw_data_to_backup()

# %% [markdown]
# ### Clear databases

# %%
def empty_raw():
    raw_tables = query("SELECT name FROM sqlite_master WHERE type='table'", con='raw')
    con = get_con_raw()
    cur = con.cursor()
    for name in raw_tables:
        print(name[0])
        cur.execute(f"DROP TABLE IF EXISTS {name[0]}")
    con.commit()
    cur.execute("VACUUM;")

# empty_raw()

# %%
def empty_main():
    main_tables = query("SELECT name FROM sqlite_master WHERE type='table'", con='main')
    con = get_con_main()
    cur = con.cursor()
    for name in main_tables:
        print(name[0])
        cur.execute(f"DROP TABLE IF EXISTS {name[0]}")
    con.commit()
    cur.execute("VACUUM;")

# empty_main()

# %% [markdown]
# ---
# ---
# # `3-county_and_dist_tables`
#
# [BACK TO TOP ^](#top-of-page)
#
# ---
# ---

# %% [markdown]
# # Reference tables: `county` and `district`
# ---
# - Standardize key to reference with other tables in the future
# - Store additional info for each county and district
# - Use **Google Maps V3 API** to collect geographic points for the center of each county and district

# %% [markdown]
# ## School Districts
# - This will be difficult. There is no standard naming convention for districts, and many datasets have typos.
# - Also, geo borders and address info are found in two different datasets (which, of course, use different naming conventions for districts)
# - The `dist_grad_rate` dataset is the only one we've found which provides a county for each school district

# %%
head(
    read_raw('districts'),
    read_raw('dist_grad_rate')
)
# Out:
# 19 cols x 178 rows
#                                             the_geom  gid   lgid  \
# 0  MULTIPOLYGON (((-106.59904239399998 39.0362792...  443   8900
# 1  MULTIPOLYGON (((-102.43672348799998 39.5852515...  444  64929
# 2  MULTIPOLYGON (((-104.28505092499995 39.5649584...  445  64908
#
#                   source modneeded generalize  priority     lastupdate    id  \
# 0  Census TIGER SHP 2014      None       None         0  December 2015  1793
# 1  Census TIGER SHP 2014      None       None         0  December 2015   217
# 2  Census TIGER SHP 2014      None       None         0  December 2015   857
#
#    lgtypeid  lgstatusid                        abbrev_nam  \
# 0        99           1  Buena Vista R-31 School District
# 1        99           1  Burlington RE-6J School District
# 2        99           1         Byers 32J School District
#
#               mail_addre alt_addres    mail_city mail_state mail_zip  \
# 0            PO Box 2027       None  Buena Vista         CO    81211
# 1             PO Box 369       None   Burlington         CO    80807
# 2  444 East Front Street       None        Byers         CO    80103
#
#                      url prev_name
# 0      www.bvschools.org      None
# 1  www.burlingtonk12.org      None
# 2     byers32j.k12.co.us      None
# 38 cols x 185 rows
#   County Name  Organization Code           Organization Name  \
# 0        None               9999                 STATE TOTAL
# 1       ADAMS                 10                  MAPLETON 1
# 2       ADAMS                 20  ADAMS 12 FIVE STAR SCHOOLS
#
#    Students with Disabilities Final Grad Base  \
# 0                                        5775
# 1                                          49
# 2                                         250
#
#    Students with Disabilities Graduates Total  \
# 0                                        3099
# 1                                          18
# 2                                         118
#
#    Students with Disabilities Graduation Rate  \
# 0                                        53.7
# 1                                        36.7
# 2                                        47.2
#
#    Students with Disabilities Completers Total  \
# 0                                         3222
# 1                                           19
# 2                                          127
#
#    Students with Disabilities Completion Rate  \
# 0                                        55.8
# 1                                        38.8
# 2                                        50.8
#
#    Limited English Proficient Final Grad Base  \
# 0                                        6171
# 1                                         219
# 2                                         379
#
#    Limited English Proficient Graduates Total  ...  Homeless Final Grad Base  \
# 0                                        3289  ...                      2394
# 1                                          73  ...                        41
# 2                                         257  ...                       106
#
#    Homeless Graduates Total  Homeless Graduation Rate  \
# 0                      1175                      49.1
# 1                        12                      29.3
# 2                        62                      58.5
#
#    Homeless Completers Total  Homeless Completion Rate  \
# 0                       1262                      52.7
# 1                         16                      39.0
# 2                         65                      61.3
#
#    Gifted-Talented Final Grad Base  Gifted-Talented Graduates Total  \
# 0                             6604                             6048
# 1                               44                               27
# 2                              227                              201
#
#    Gifted-Talented Graduation Rate  Gifted-Talented Completers Total  \
# 0                             91.6                              6156
# 1                             61.4                                27
# 2                             88.5                               208
#
#    Gifted-Talented Completion Rate
# 0                             93.2
# 1                             61.4
# 2                             91.6
#
# [3 rows x 38 columns]

# %%
dist_info = read_raw("""
    abbrev_nam AS district,
    the_geom AS geo_border,
    gid,
    lgid,
    id,
    mail_addre AS street,
    mail_city AS city,
    mail_state AS state,
    mail_zip AS zip,
    url
""",
FROM='districts'
)
head(dist_info)
# Out:
# 10 cols x 178 rows
#                            district  \
# 0  Buena Vista R-31 School District
# 1  Burlington RE-6J School District
# 2         Byers 32J School District
#
#                                           geo_border  gid   lgid    id  \
# 0  MULTIPOLYGON (((-106.59904239399998 39.0362792...  443   8900  1793
# 1  MULTIPOLYGON (((-102.43672348799998 39.5852515...  444  64929   217
# 2  MULTIPOLYGON (((-104.28505092499995 39.5649584...  445  64908   857
#
#                   street         city state    zip                    url
# 0            PO Box 2027  Buena Vista    CO  81211      www.bvschools.org
# 1             PO Box 369   Burlington    CO  80807  www.burlingtonk12.org
# 2  444 East Front Street        Byers    CO  80103     byers32j.k12.co.us

# %%
dist_county = read_raw("""
    `Organization Name` AS district,
    `Organization Code` AS code,
    `County Name` AS in_county
""",
FROM="dist_grad_rate",
WHERE="district != 'STATE TOTAL'"
)
head(dist_county)
# Out:
# 3 cols x 183 rows
#                      district  code in_county
# 0                  MAPLETON 1    10     ADAMS
# 1  ADAMS 12 FIVE STAR SCHOOLS    20     ADAMS
# 2             ADAMS COUNTY 14    30     ADAMS

# %% [markdown]
# ## Standardize district naming conventions
# ---

# %%
# standardize_district_name and join_conflicts defined in workspace setup
dist_info.district = dist_info.district.apply(standardize_district_name)
dist_county.district = dist_county.district.apply(standardize_district_name)

# See keys that aren't shared
dist_diff = join_conflicts(dist_info, dist_county, 'district')
dist_diff
# Out:
#       0                       1
# 0  None         CENTENNIALBOCES
# 1  None  CHARTERSCHOOLINSTITUTE
# 2  None      EXPEDITIONARYBOCES
# 3  None           MOUNTAINBOCES
# 4  None            SANJUANBOCES

# %% [markdown]
# #### Some districts have invalid counties listed. Fix it

# %%
dist_to_county_map = {
    # Where district == key, set county to val
    'CUSTERCOUNTY 1': 'CUSTER',
    'CHARTERSCHOOLINSTITUTE': 'DENVER',
    'MOUNTAINBOCES': 'CHAFFEE',
    'CENTENNIALBOCES': 'WELD',
    'SANJUANBOCES': 'LA PLATA',
    'EXPEDITIONARYBOCES': 'DENVER',
}
for dist_name, new_county_name in dist_to_county_map.items():
    dist_county.loc[dist_county.district == dist_name, 'in_county'] = new_county_name

# %% [markdown]
# ### Merge district tables

# %%
district = dist_county.merge(dist_info, on='district', how='left')
head(district, with_tail=True)
# Out:
# 12 cols x 183 rows
#                district  code in_county  \
# 0            MAPLETON 1    10     ADAMS
# 1      ADAMSFIVESTAR 12    20     ADAMS
# 181        SANJUANBOCES  9050  LA PLATA
# 182  EXPEDITIONARYBOCES  9130    DENVER
#
#                                             geo_border    gid    lgid      id  \
# 0    MULTIPOLYGON (((-105.01581612299998 39.8144774...  593.0  1900.0  2210.0
# 1    MULTIPOLYGON (((-105.05310614499996 39.9302934...  648.0  1901.0  2211.0
# 181                                                NaN    NaN     NaN     NaN
# 182                                                NaN    NaN     NaN     NaN
#
#                     street      city state    zip               url
# 0    5910 East 80th Avenue    Denver    CO  80229  www.mapleton.us/
# 1      1500 E 128th Avenue  Thornton    CO  80241   www.adams12.org
# 181                    NaN       NaN   NaN    NaN               NaN
# 182                    NaN       NaN   NaN    NaN               NaN

# %% [markdown]
# ## County

# %%
county = read_raw("""
    COUNTY as county,
    the_geom as geo_border
""",
FROM="counties"
)
head(county)
# Out:
# 2 cols x 64 rows
#      county                                         geo_border
# 0     ADAMS  MULTIPOLYGON (((-103.70574149517748 39.9999110...
# 1   ALAMOSA  MULTIPOLYGON (((-105.59917426201822 37.7521648...
# 2  ARAPAHOE  MULTIPOLYGON (((-103.70653410023402 39.7398580...

# %% [markdown]
# # Geocoding - Google Maps V3 API

# %%
from geopy.geocoders import GoogleV3
import geopandas as gp
api_kwargs = dict(provider = 'google', api_key = 'NVmnFlQnc_MiOFcCoz7dwIFmVgq5f1zncXCdwJp')

# %% [markdown]
# ### County

# %%
try:
    county['geo_point'] = (
        gp.tools
        .geocode(county.county.str.capitalize() + " County, Colorado", **api_kwargs)
        ['geometry']
        .astype(str)
    )
except Exception:
    county['geo_point'] = np.nan
head(county)
# Out:
# 3 cols x 64 rows
#      county                                         geo_border  \
# 0     ADAMS  MULTIPOLYGON (((-103.70574149517748 39.9999110...
# 1   ALAMOSA  MULTIPOLYGON (((-105.59917426201822 37.7521648...
# 2  ARAPAHOE  MULTIPOLYGON (((-103.70653410023402 39.7398580...
#
#                   geo_point
# 0  GEOMETRYCOLLECTION EMPTY
# 1  GEOMETRYCOLLECTION EMPTY
# 2  GEOMETRYCOLLECTION EMPTY

# %%
write_main(county, 'county')
# Out:
# 64

# %% [markdown]
# ### School District

# %% [markdown]
# Add full address column for geocoder to use

# %%
district.insert(0, 'address', (
    district.loc[
        ~ district.street.isna(),
        ['street', 'city', 'state', 'zip']
    ]
    .agg(', '.join, axis=1)
))

# %%
head(district, with_tail=True)
# Out:
# 13 cols x 183 rows
#                                       address            district  code  \
# 0    5910 East 80th Avenue, Denver, CO, 80229          MAPLETON 1    10
# 1    1500 E 128th Avenue, Thornton, CO, 80241    ADAMSFIVESTAR 12    20
# 181                                       NaN        SANJUANBOCES  9050
# 182                                       NaN  EXPEDITIONARYBOCES  9130
#
#     in_county                                         geo_border    gid  \
# 0       ADAMS  MULTIPOLYGON (((-105.01581612299998 39.8144774...  593.0
# 1       ADAMS  MULTIPOLYGON (((-105.05310614499996 39.9302934...  648.0
# 181  LA PLATA                                                NaN    NaN
# 182    DENVER                                                NaN    NaN
#
#        lgid      id                 street      city state    zip  \
# 0    1900.0  2210.0  5910 East 80th Avenue    Denver    CO  80229
# 1    1901.0  2211.0    1500 E 128th Avenue  Thornton    CO  80241
# 181     NaN     NaN                    NaN       NaN   NaN    NaN
# 182     NaN     NaN                    NaN       NaN   NaN    NaN
#
#                   url
# 0    www.mapleton.us/
# 1     www.adams12.org
# 181               NaN
# 182               NaN

# %%
district['geo_point'] = np.nan
try:
    district.loc[ ~ district.address.isna(), 'geo_point'] = (
        gp.tools
        .geocode(district.address, **api_kwargs)
        ['geometry']
        .astype(str)
    )
except Exception:
    district['geo_point'] = np.nan

district = (district
    .drop_cols('address')
    .move_col('geo_point', 4)
)
head(district, with_tail=True)
# Out:
# 13 cols x 183 rows
#                district  code in_county  \
# 0            MAPLETON 1    10     ADAMS
# 1      ADAMSFIVESTAR 12    20     ADAMS
# 181        SANJUANBOCES  9050  LA PLATA
# 182  EXPEDITIONARYBOCES  9130    DENVER
#
#                                             geo_border  \
# 0    MULTIPOLYGON (((-105.01581612299998 39.8144774...
# 1    MULTIPOLYGON (((-105.05310614499996 39.9302934...
# 181                                                NaN
# 182                                                NaN
#
#                     geo_point    gid    lgid      id                 street  \
# 0    GEOMETRYCOLLECTION EMPTY  593.0  1900.0  2210.0  5910 East 80th Avenue
# 1    GEOMETRYCOLLECTION EMPTY  648.0  1901.0  2211.0    1500 E 128th Avenue
# 181                       NaN    NaN     NaN     NaN                    NaN
# 182                       NaN    NaN     NaN     NaN                    NaN
#
#          city state    zip               url
# 0      Denver    CO  80229  www.mapleton.us/
# 1    Thornton    CO  80241   www.adams12.org
# 181       NaN   NaN    NaN               NaN
# 182       NaN   NaN    NaN               NaN

# %%
write_main(district, 'district')
# Out:
# 183

# %% [markdown]
# ---
# ---
# # `4-county_demographics`
#
# [BACK TO TOP ^](#top-of-page)
#
# ---
# ---

# %% [markdown]
# # County Demographics
# ---
#
# ### Why use a separate dataset for population?
# - Most population groups are present in the census data (gender, age, etc.) So why use an additional population dataset instead?
#   - The population dataset claims to provide "actual" numbers, whereas the census data claims to provide "estimates"
#   - The population dataset is more precise, with age groups of each individual age number, allowing us to make our own aggregated bins (adult, minor). The census data has age groups defined already, but in increments of 5, so the middle group is "15 to 19", but we need 18 and under!
#   - The population dataset offers sub-aggregations: we have `minor_female` and `minor_male`, for instance, whereas the census data only offers age populations and gender populations separately
# - So instead, we will use population dataset first, and add in additional groups from census data

# %%
INDEX = ['year', 'county']

# %% [markdown]
# ## Population
#
# > This data will supplement our census data in the next step of data prep. We're using the Population dataset because it's more accurate (census is just estimates), and it lets us create the age grouping ourselves. There are nearly 400,000 rows, because they give us population by year, county, and EACH individual age. In our case, we want to create an age grouping that separates students in school, and adults. So we chose >= 19, and < 19. It also has a 60 year timeframe. So number of rows = 60 years * 64 counties * 90 years of age.

# %%
df_raw = read_raw("""
    year,
    UPPER(county) AS county,
    age,
    malePopulation AS male,
    femalePopulation AS female,
    totalPopulation AS total
""",
FROM="county_population"
)
head(df_raw)
# Out:
# 6 cols x 381504 rows
#    year county  age  male  female  total
# 0  1990  ADAMS    0  2354    2404   4758
# 1  1990  ADAMS    1  2345    2375   4720
# 2  1990  ADAMS    2  2413    2219   4632

# %% [markdown]
# ### Age groups (< 19, >= 19)

# %%
df = df_raw.coerce_type(float, exclude=['year'])
df['age_range'] = "over18"
df.loc[df.age <= 18, 'age_range'] = 'under19'
df = df.drop_cols('age')
head(df)

df = (df
    .groupby(INDEX + ['age_range'])
    .sum()
    .reset_index()
)
df_grouped = df
head(df_grouped)
# Out:
# 6 cols x 381504 rows
#    year county    male  female   total age_range
# 0  1990  ADAMS  2354.0  2404.0  4758.0   under19
# 1  1990  ADAMS  2345.0  2375.0  4720.0   under19
# 2  1990  ADAMS  2413.0  2219.0  4632.0   under19
# 6 cols x 7808 rows
#    year   county age_range     male   female     total
# 0  1990    ADAMS    over18  90383.0  94282.0  184665.0
# 1  1990    ADAMS   under19  41519.0  39525.0   81044.0
# 2  1990  ALAMOSA    over18   4488.0   4823.0    9311.0

# %% [markdown]
# ### Notice the `age_range` column. We should pivot those values out to their own columns, and mix with our existing columns
# - First, pivot age_range into the male, female, and total columns
# - We're left with a multilevel column index, so we drop a level and rename everything by hand.
# - Lastly, restore the total, male, and female columns since they got split in half when pivoting.

# %%
df = (df_grouped
    .pivot(
        index=INDEX,
        columns='age_range',
        values=['male', 'female', 'total']
    )
    .reset_multilevel_columns(INDEX + ['over18', 'under19', 'under19_male', 'under19_female', 'over18_male', 'over18_female'])
)

df = (df
    .insert_at(2, 'female', df.under19_female + df.over18_female)
    .insert_at(2, 'male', df.under19_male + df.over18_male)
    .insert_at(2, 'total', df.under19 + df.over18)
)

pop_raw = df
head(pop_raw)
# Out:
# 11 cols x 3904 rows
#    year    county     total      male    female    over18  under19  \
# 0  1990     ADAMS  131902.0  278947.0  120569.0   90383.0  41519.0
# 1  1990   ALAMOSA    6677.0   14134.0    6423.0    4488.0   2189.0
# 2  1990  ARAPAHOE  191722.0  428121.0  166735.0  134481.0  57241.0
#
#    under19_male  under19_female  over18_male  over18_female
# 0       94282.0         39525.0     184665.0        81044.0
# 1        4823.0          2117.0       9311.0         4306.0
# 2      146820.0         54747.0     281301.0       111988.0

# %%
write_main(pop_raw, 'county_population')
# Out:
# 3904

# %% [markdown]
# ---
# ---
# ---

# %% [markdown]
# ## Census Field Descriptions
# ---
# - To supplement the "Census Counties ..." datasets, they've provided us a table with descriptions of each column name, for each historical standard of the census. Fortunately, the 2019 and 2012 census data (that's what we're using) uses the same standard: `acs_standard`
# - This script does the following:
#   - Filters the source dataframe to only include `acs_standard` column descriptions
#   - Selects only necessary columns (column name, description)
#   - Renames some values in column name, and removes some column name values we'll never use (geonum, geojson)

# %%
desc = read_raw("""
        apifieldname AS field_name,
        description
    """,
    FROM = "census_counties_field_desc",
    WHERE = "type = 'acs_standard' AND field_name NOT IN ('geonum', 'geojson')"
)
desc.loc[desc.field_name == 'geoname', 'field_name'] = 'county'

write_main(desc, 'census_counties_field_desc')

head(desc)
# Out:
# 2 cols x 155 rows
#   field_name                                   description
# 0     county                   Geographic Area common name
# 1        pop  Population Estimate for the given time range
# 2   hispanic          Estimate for the Hispanic Population

# %% [markdown]
# ---
# ---
# ---

# %% [markdown]
# # Engineering Census data
# - Prepare census data for a variety of uses, such as visualization, aggregation and predictive modeling

# %%
# Each census year comes in a separate dataset
dem = (
    pd.concat([
            (read_raw(f'census_counties_{year}')
                .drop_cols('pop', 'geonum', 'the_geom')
                .assign(year=year)
                .rename_col('civ_ni_','civ_ni_p')
            )
        for year in range(2012, 2020)
    ])
    .copy() # avoid fragmentation caused by assign()
    .rename_col('geoname','county')
    .move_col('year', 0)
    .coerce_type(float, exclude='year')
)

dem.county = (
    dem.county
    .str.replace(" County, Colorado", "")
    .str.upper()
)
head(dem)
# Out:
# 155 cols x 512 rows
#    year    county  hispanic  white_nh  black_nh  ntvam_nh  asian_nh  hawpi_nh  \
# 0  2012  ARAPAHOE  105174.0  364766.0   55629.0    2211.0   28067.0    1166.0
# 1  2012   MINERAL      15.0     671.0       9.0       5.0       1.0       0.0
# 2  2012  MONTROSE    8037.0   31799.0     186.0      74.0     227.0      49.0
#
#    other_nh  twoplus_nh  ...  civ_ni_pop  disabled  pop16_pls  laborforce  \
# 0    1267.0     16077.0  ...    568663.0   49870.0   444215.0    320199.0
# 1       0.0         1.0  ...       702.0     129.0      681.0       391.0
# 2      33.0       589.0  ...     40552.0    5649.0    32334.0     20137.0
#
#      civ_lf       emp    unemp  armedfrcs    not_lf  civ_ni_p
# 0  318041.0  292089.0  25952.0     2158.0  124016.0  568663.0
# 1     391.0     370.0     21.0        0.0     290.0     702.0
# 2   20124.0   18110.0   2014.0       13.0   12197.0   40552.0
#
# [3 rows x 155 columns]

# %% [markdown]
# #### Select desired columns from census data

# %%
df = dem.copy()[INDEX + [
    'med_age',
    'households', 'avghhsize',
    'civ_lf', 'emp', 'unemp',
    'hispanic', 'white_nh', 'black_nh', 'asian_nh', 'ntvam_nh', 'hawpi_nh', 'other_nh', 'twoplus_nh',
    'pop25plus', 'hsgrad_sc',
    'med_hh_inc', 'per_cap_in',
    'citz_birth', 'citz_nat', 'born_in_co',
    'pop_3pl', 'enrolled', 'undergrad',
    'gr_1_4', 'gr_5_8', 'gr_9_12',
    'med_hm_val', 'med_yr_blt',
    'housing_un', 'occ_hu',
    'own_occ_hu', 'v_l_50k', 'v50k_100k', 'v100k_150k', 'v150k_200k', 'v200k_250k', 'v250k_300k',
    'v300k_400k', 'v400k_500k', 'v500k_750k', 'v750k_1m', 'v_1m_plus',
    'b2000_2009', 'b1990_1999', 'b1980_1989', 'b1970_1979',
    'b1960_1969', 'b1950_1959', 'b1940_1949', 'b1939_e',
    'ps_uni', 'ps_below',
    'tot_l18', 'pov_l18',
]]

# %% [markdown]
# #### Group bins together

# %%
from typing import Callable
@Extend(pd.DataFrame)
def combine_cols(
    self,
    name: str | None = None,
    cols: list | None = None,
    items: dict | None = None,
    replace: bool = True,
    func: Callable[[Iterable[Any]], int | float] = sum
) -> pd.DataFrame:
    """
    Given a list of column names, create a new column with their sum, and
    position it before the first col in 'cols'. So if replace=True, then
    the old columns will effectively be replaced in their original position.
    To do multiple sums, pass 'items' as dict with names as keys and col list as vals
    """
    df = self.copy()
    if not items:
        items = {name: cols}
    for name, cols in items.items():
        new = func([df[c] for c in cols])
        df = df.insert_at(cols[0], name, new)
        if replace:
            df = df.drop_cols(cols)
    return df

# %%
# Create new variable for total citizens. Place it next to citz_birth
df = (df
    .insert_at('citz_birth', 'citz', df.citz_birth + df.citz_nat)
    .drop_cols('citz_nat')
    .combine_cols(items={
        'race_other': ['ntvam_nh', 'hawpi_nh', 'other_nh', 'twoplus_nh'],
        'b1949_e': ['b1939_e', 'b1940_1949'],
        'v50k_150k':  ['v50k_100k', 'v100k_150k'],
        'v150k_250k': ['v150k_200k', 'v200k_250k'],
        'v250k_400k': ['v250k_300k', 'v300k_400k'],
        'v400k_750k': ['v400k_500k', 'v500k_750k'],
        'v750k_plus': ['v750k_1m', 'v_1m_plus'],
    })
)
head(df)
# Out:
# 48 cols x 512 rows
#    year    county  med_age  households  avghhsize    civ_lf       emp  \
# 0  2012  ARAPAHOE     35.7    223747.0       2.55  318041.0  292089.0
# 1  2012   MINERAL     60.3       363.0       1.83     391.0     370.0
# 2  2012  MONTROSE     42.6     16732.0       2.41   20124.0   18110.0
#
#      unemp  hispanic  white_nh  ...  b1990_1999  b1980_1989  b1970_1979  \
# 0  25952.0  105174.0  364766.0  ...     33989.0     56011.0     62253.0
# 1     21.0      15.0     671.0  ...       232.0       239.0       203.0
# 2   2014.0    8037.0   31799.0  ...      3750.0      2106.0      3581.0
#
#    b1960_1969  b1950_1959  b1949_e    ps_uni  ps_below   tot_l18  pov_l18
# 0     22258.0     16519.0   7165.0  568999.0   66945.0  144576.0  23054.0
# 1       100.0        75.0    240.0     702.0      47.0      26.0      0.0
# 2      1298.0       920.0   2333.0   40368.0    5565.0    9788.0   1927.0
#
# [3 rows x 48 columns]

# %% [markdown]
# #### Create nominal variables for housing price and housing age
# - First, create a categorical variable whose values are the COLUMN NAME of the bin with the max value. For instance, if a given county has more houses in the `v50k_100k` range than any other range, the value at that row in the new column will be "v50k_100k"
# - Next, create a nominal column from that categorical column, ordered so that a lower number means less desirable. So for prices, "v_l_50k" -> 1, and for year built, "b1939_e" -> 1

# %%
@Extend(pd.DataFrame)
class _:
    def add_ordinal(
        self,
        col: str,
        order: list,
        replace: bool = False
    ) -> pd.DataFrame:
        """
        Create ordinal col from existing categorical col. Pass an ascending list
        of categories. Example: Input ['A', 'B', 'C'] -> New column map: {'A': 1, 'B': 2, 'C': 3}
        """
        df = self.copy()
        new = self[col].map({k: i+1 for i, k in enumerate(order)})
        df = df.insert_at(col, f'{col}_ord', new)
        if replace:
            df = df.drop_cols(col)
        return df

    def add_binmax(
        self,
        name: str,
        cols: list,
        replace: bool = False
    ) -> pd.DataFrame:
        """
        Shorthand for df.idxmax(), but lets you choose location and replace given columns
        """
        df = self.copy()
        new = self[cols].idxmax(axis=1)
        df = df.insert_at(cols[0], name, new)
        if replace:
            df = df.drop_cols(cols)
        return df

# %%
blt_ascending = ['b1949_e','b1950_1959','b1960_1969','b1970_1979','b1980_1989','b1990_1999','b2000_2009']
prices_ascending = ['v_l_50k', 'v50k_150k', 'v150k_250k', 'v250k_400k', 'v400k_750k', 'v750k_plus']
df = (df
    .add_binmax('blt_freq_yr', blt_ascending)
    .add_ordinal('blt_freq_yr', blt_ascending)
    .add_binmax('hu_freq_val', prices_ascending)
    .add_ordinal('hu_freq_val', prices_ascending)
)

# %% [markdown]
# ---

# %% [markdown]
# #### Rename columns in population and census data with a naming system that uses consistent prefixes to let us easily select groups and sub-groups of columns with a simple string match

# %%
rename_pop = pd.read_excel('column_renaming.xlsx', sheet_name='population_rename')

rename_dem = pd.read_excel('column_renaming.xlsx', sheet_name='census_rename')

display(rename_pop.fillna(''), rename_dem.fillna(''))

pop = pop_raw.rename_cols_from_df(rename_pop.dropna())
df = df.rename_cols_from_df(rename_dem.dropna())
# Out:
#                OLD                NEW
# 0            total                pop
# 1
# 2             male             gend_m
# 3           female             gend_f
# 4
# 5           over18         age_over18
# 6          under19         age_undr19
# 7
# 8      over18_male  gend_m_age_over18
# 9    over18_female  gend_f_age_over18
# 10    under19_male  gend_m_age_undr19
# 11  under19_female  gend_f_age_undr19
#                 OLD                 NEW
# 0           med_age          age_median
# 1
# 2        per_cap_in         inc_per_cap
# 3        med_hh_inc       inc_hh_median
# 4
# 5        households                  hh
# 6         avghhsize         hh_size_avg
# 7
# 8         pop25plus         hsgrad_pool
# 9         hsgrad_sc    hsgrad_graduated
# 10
# 11       born_in_co             citz_co
# 12       citz_birth          citz_birth
# 13
# 14              emp     civ_lf_employed
# 15
# 16         hispanic       race_hispanic
# 17         white_nh          race_white
# 18         black_nh          race_black
# 19         asian_nh          race_asian
# 20
# 21           ps_uni            ps_known
# 22         ps_below            ps_below
# 23          tot_l18     ps_undr18_known
# 24          pov_l18     ps_undr18_below
# 25
# 26          pop_3pl    stud_enroll_pool
# 27         enrolled       stud_enrolled
# 28        undergrad      stud_undergrad
# 29           gr_1_4            stud_1_4
# 30           gr_5_8            stud_5_8
# 31          gr_9_12           stud_9_12
# 32
# 33       housing_un                  hu
# 34           occ_hu              hu_occ
# 35
# 36      blt_freq_yr      hu_blt_freq_yr
# 37  blt_freq_yr_ord  hu_blt_freq_yr_ord
# 38          b1949_e      hu_blt_lt_1950
# 39       b1950_1959    hu_blt_1950_1959
# 40       b1960_1969    hu_blt_1960_1969
# 41       b1970_1979    hu_blt_1970_1979
# 42       b1980_1989    hu_blt_1980_1989
# 43       b1990_1999    hu_blt_1990_1999
# 44       b2000_2009    hu_blt_2000_plus
# 45
# 46       own_occ_hu               hu_oo
# 47      hu_freq_val      hu_oo_freq_val
# 48  hu_freq_val_ord  hu_oo_freq_val_ord
# 49          v_l_50k         hu_oo_lt_50
# 50        v50k_150k        hu_oo_50_150
# 51       v150k_250k       hu_oo_150_250
# 52       v250k_400k       hu_oo_250_400
# 53       v400k_750k       hu_oo_400_750
# 54       v750k_plus      hu_oo_750_plus

# %% [markdown]
# ## Merge population and census data

# %%
main = (pop
    .merge(df, on=INDEX)
    .move_col('age_median', 'age_over18')
)
head(main)
# Out:
# 61 cols x 512 rows
#    year    county       pop    gend_m    gend_f  age_median  age_over18  \
# 0  2012     ADAMS  231571.0  487410.0  201960.0        32.4    162109.0
# 1  2012   ALAMOSA    7823.0   17115.0    6283.0        32.2      5622.0
# 2  2012  ARAPAHOE  292548.0  666719.0  233180.0        35.7    212207.0
#
#    age_undr19  gend_m_age_undr19  gend_f_age_undr19  ...  hu_blt_1970_1979  \
# 0     69462.0           162653.0            66249.0  ...           30185.0
# 1      2201.0             5748.0             2044.0  ...            1405.0
# 2     80341.0           227254.0            76419.0  ...           62253.0
#
#    hu_blt_1960_1969  hu_blt_1950_1959  hu_blt_freq_yr_ord  hu_blt_freq_yr  \
# 0           19615.0           20369.0                   7      b2000_2009
# 1             654.0             591.0                   1         b1949_e
# 2           22258.0           16519.0                   4      b1970_1979
#
#    hu_blt_lt_1950  ps_known  ps_below  ps_undr18_known  ps_undr18_below
# 0          6158.0  438171.0   62008.0         124375.0          25278.0
# 1          1536.0   14622.0    3191.0           3817.0            758.0
# 2          7165.0  568999.0   66945.0         144576.0          23054.0
#
# [3 rows x 61 columns]

# %% [markdown]
# ## Calculations for groups
# ---

# %%
# GroupedDF defined in workspace setup
GroupedDF.default_index = INDEX
GroupedDF.set_groups(['age', 'gend', 'race', 'inc', 'hh', 'citz', 'hsgrad', 'civ_lf', 'ps', 'stud', 'hu', 'hu_blt', 'hu_oo'])

# %%
gd = GroupedDF(main, INDEX, custom={'hu': INDEX + ['hu', 'hu_occ']})
gd.display(3)
# Out:
# age:
#    year    county  age_median  age_over18  age_undr19
# 0  2012     ADAMS        32.4    162109.0     69462.0
# 1  2012   ALAMOSA        32.2      5622.0      2201.0
# 2  2012  ARAPAHOE        35.7    212207.0     80341.0
# gend:
#    year    county    gend_m    gend_f  gend_m_age_undr19  gend_f_age_undr19  \
# 0  2012     ADAMS  487410.0  201960.0           162653.0            66249.0
# 1  2012   ALAMOSA   17115.0    6283.0             5748.0             2044.0
# 2  2012  ARAPAHOE  666719.0  233180.0           227254.0            76419.0
#
#    gend_m_age_over18  gend_f_age_over18
# 0           324757.0           135711.0
# 1            11367.0             4239.0
# 2           439465.0           156761.0
# race:
#    year    county  race_hispanic  race_white  race_black  race_asian  \
# 0  2012     ADAMS       167556.0    235991.0     12970.0     15304.0
# 1  2012   ALAMOSA         7185.0      7767.0       110.0        59.0
# 2  2012  ARAPAHOE       105174.0    364766.0     55629.0     28067.0
#
#    race_other
# 0     11175.0
# 1       629.0
# 2     20721.0
# inc:
#    year    county  inc_hh_median  inc_per_cap
# 0  2012     ADAMS        56633.0      24357.0
# 1  2012   ALAMOSA        38045.0      19657.0
# 2  2012  ARAPAHOE        60400.0      32845.0
# hh:
#    year    county        hh  hh_size_avg
# 0  2012     ADAMS  151034.0         2.91
# 1  2012   ALAMOSA    5853.0         2.49
# 2  2012  ARAPAHOE  223747.0         2.55
# citz:
#    year    county      citz  citz_birth   citz_co
# 0  2012     ADAMS  396172.0    376454.0  223907.0
# 1  2012   ALAMOSA   15122.0     14868.0    9542.0
# 2  2012  ARAPAHOE  519940.0    487576.0  223433.0
# hsgrad:
#    year    county  hsgrad_pool  hsgrad_graduated
# 0  2012     ADAMS     275628.0          166731.0
# 1  2012   ALAMOSA       9424.0            5946.0
# 2  2012  ARAPAHOE     378792.0          199197.0
# civ_lf:
#    year    county    civ_lf  civ_lf_employed
# 0  2012     ADAMS  236110.0         213794.0
# 1  2012   ALAMOSA    7171.0           6449.0
# 2  2012  ARAPAHOE  318041.0         292089.0
# ps:
#    year    county  ps_known  ps_below  ps_undr18_known  ps_undr18_below
# 0  2012     ADAMS  438171.0   62008.0         124375.0          25278.0
# 1  2012   ALAMOSA   14622.0    3191.0           3817.0            758.0
# 2  2012  ARAPAHOE  568999.0   66945.0         144576.0          23054.0
# stud:
#    year    county  stud_enroll_pool  stud_enrolled  stud_undergrad  stud_1_4  \
# 0  2012     ADAMS          420756.0       117499.0         19299.0   28761.0
# 1  2012   ALAMOSA           14903.0         5362.0          2285.0     736.0
# 2  2012  ARAPAHOE          549701.0       153854.0         29388.0   33703.0
#
#    stud_5_8  stud_9_12
# 0   26645.0    24342.0
# 1     801.0      890.0
# 2   30902.0    33425.0
# hu:
#    year    county        hu    hu_occ
# 0  2012     ADAMS  163245.0  151034.0
# 1  2012   ALAMOSA    6572.0    5853.0
# 2  2012  ARAPAHOE  238160.0  223747.0
# hu_blt:
#    year    county  hu_blt_2000_plus  hu_blt_1990_1999  hu_blt_1980_1989  \
# 0  2012     ADAMS           38682.0           27598.0           20368.0
# 1  2012   ALAMOSA             650.0             866.0             862.0
# 2  2012  ARAPAHOE           39415.0           33989.0           56011.0
#
#    hu_blt_1970_1979  hu_blt_1960_1969  hu_blt_1950_1959  hu_blt_freq_yr_ord  \
# 0           30185.0           19615.0           20369.0                   7
# 1            1405.0             654.0             591.0                   1
# 2           62253.0           22258.0           16519.0                   4
#
#   hu_blt_freq_yr  hu_blt_lt_1950
# 0     b2000_2009          6158.0
# 1        b1949_e          1536.0
# 2     b1970_1979          7165.0
# hu_oo:
#    year    county     hu_oo  hu_oo_freq_val_ord hu_oo_freq_val  hu_oo_lt_50  \
# 0  2012     ADAMS  100108.0                   3     v150k_250k       8578.0
# 1  2012   ALAMOSA    3702.0                   2      v50k_150k        435.0
# 2  2012  ARAPAHOE  143158.0                   3     v150k_250k       4207.0
#
#    hu_oo_50_150  hu_oo_150_250  hu_oo_250_400  hu_oo_400_750  hu_oo_750_plus
# 0       19838.0        47583.0        17779.0         5427.0           903.0
# 1        1599.0         1077.0          397.0          177.0            17.0
# 2       22174.0        55935.0        38213.0        16339.0          6290.0

# %% [markdown]
# ## Calculations
# ---
#
# - **age, and gend**
#   - `age_median`: (Existing)
#   - `age_undr19_prop`: What percent of the population is under 19?
#   - `gend_m_prop`: What percent of the population is male?
#   - `age_undr19_gend_m_prop`: What percent of under-19 year old are male? (divide m_undr19 by undr19)
# - **inc**
#   - `inc_hh_med`: (Existing) Median household income
#   - `inc_per_cap`: (Existing) Per capita income
# - **hh**
#   - `hh_size_avg`: (Existing) Average household size
# - **race**
#   - `race_{x}_prop`: What percent of the population is race x?
#   - `race_prop_stdev`: What is the standard deviation of the race proportions? We need to calculate the proportions first, to normalize for the population size, that way, we can compare the standard deviations across groups
# - **hsgrad**
#   - `hsgrad_graduated_prop`: What percent of adults (age 25+) have a high school diploma or equivalent?
# - **civ_lf**
#   - `civ_lf_prop`: What percent of the population is in the civilian labor force?
#   - `civ_lf_employed_prop`: What percent of the civilian labor force is employed?
# - **ps**
#   - `ps_total_prop`: What percent of people whose poverty status is known are below the poverty line?
#   - `ps_undr18_total_prop`: What percent of under-18 people whose poverty status is known are below the poverty line?
#   - `ps_undr18_prop`: What percent of people below the poverty line are under 18?
# - **stud**
#   - `stud_enrolled_prop`: Percent of people who could be enrolled in school that actually are enrolled
#   - `stud_hs_prop`: What percent of gradeschool students (1-12) are high schoolers? (lower number indicates dropouts, which may associate with crime)
#   - `stud_undergrad_prop`: What percent of enrolled students are undergraduates?
# - **citz**
#   - `citz_prop`: What percent of the population is a us citizen?
#   - `citz_birth_prop`: What percent of us citizens were born in the us?
#   - `citz_co_prop`: What percent of citizens were born in Colorado?
# - **hu**
#   - `hu_occ_prop`: Percent of homes which are occupied
#   - `hu_blt_after1989`: Percent of homes which were built in the past 20 years
#   - `hu_blt_nominal`: Convert hu_blt_mode_range to nominal, where the highest number corresponds to highest year range
# - **hu_oo**
#   - `hu_oo_prop`: Percent of occupied properties occupied by owner. The remaining percent is renter occupied
#   - `hu_oo_lt_50_prop`: Percent of owner occupied properties worth less than $50,000
#   - `hu_oo_750_plus_prop`: Percent of owner occupied properties worth $750,000 or more

# %%
df = main.copy()

df['age_over18_prop'] = df.age_over18 / df['pop']
df['age_undr19_prop'] = df.age_undr19 / df['pop']
df['gend_m_prop'] = df.gend_m / df['pop']
df['gend_f_prop'] = df.gend_f / df['pop']
df['age_undr19_gend_m_prop'] = df.gend_m_age_undr19 / df.age_undr19
df['age_undr19_gend_f_prop'] = df.gend_f_age_undr19 / df.age_undr19
df['age_over18_gend_m_prop'] = df.gend_m_age_over18 / df.age_over18
df['age_over18_gend_f_prop'] = df.gend_f_age_over18 / df.age_over18

df['gend_m_age_undr19_prop'] = df.gend_m_age_undr19 / df.gend_m
df['gend_m_age_over18_prop'] = df.gend_m_age_over18 / df.gend_m
df['gend_f_age_undr19_prop'] = df.gend_f_age_undr19 / df.gend_f
df['gend_f_age_over18_prop'] = df.gend_f_age_over18 / df.gend_f

race_base = GroupedDF(df, INDEX).race
race = df.copy()[INDEX]
for c in [c for c in race_base.columns if c not in INDEX]:
    race[f'{c}_prop'] = race_base[c] / df['pop']

race['race_prop_stdev'] = np.std(race.drop(columns=INDEX), axis=1)
df = df.merge(race, how='inner', on=INDEX)

df['hsgrad_graduated_prop'] = df.hsgrad_graduated / df.hsgrad_pool

df['civ_lf_prop'] = df.civ_lf / df['pop']
df['civ_lf_employed_prop'] = df.civ_lf_employed / df.civ_lf

df['ps_total_prop'] = df.ps_below / df.ps_known
df['ps_undr18_total_prop'] = df.ps_undr18_below / df.ps_undr18_known
df['ps_undr18_prop'] = df.ps_undr18_below / df.ps_below

df['stud_enrolled_prop'] = df.stud_enrolled / df.stud_enroll_pool
df['stud_hs_prop'] = df.stud_9_12 / (df.stud_1_4 + df.stud_5_8 + df.stud_9_12)
df['stud_undergrad_prop'] = df.stud_undergrad / df.stud_enrolled

df['citz_per_cap'] = df.citz / df['pop']
df['citz_birth_prop'] = df.citz_birth / df.citz
df['citz_co_prop'] = df.citz_co / df.citz

df['hu_per_cap'] = df.hu / df['pop']
df['hu_occ_prop'] = df.hu_occ / df.hu
df['hu_blt_2000_plus_prop'] = df.hu_blt_2000_plus / df.hu

df['hu_oo_prop'] = df.hu_oo / df.hu_occ

for hval in ['hu_oo_lt_50', 'hu_oo_50_150', 'hu_oo_150_250', 'hu_oo_250_400', 'hu_oo_400_750', 'hu_oo_750_plus']:
    df[f'{hval}_prop'] = df[hval] / df.hu_oo

for hyear in [
        'hu_blt_lt_1950', 'hu_blt_1950_1959', 'hu_blt_1960_1969',
        'hu_blt_1970_1979', 'hu_blt_1980_1989', 'hu_blt_1990_1999', 'hu_blt_2000_plus'
    ]:
    df[f'{hyear}_prop'] = df[hyear] / df.hu

# prop, counts = separate_by(df, ['prop', 'per_cap', 'median', 'avg', 'freq', 'med_hm_val', 'med_yr_blt'], index=INDEX)
filter_cols = ['prop', 'per_cap', 'median', 'avg', 'freq', 'med_hm_val', 'med_yr_blt']
prop = df.separate_by(filter_cols, index=INDEX, mode='include')
counts = df.separate_by(filter_cols, index=INDEX, mode='exclude')

gprop = GroupedDF(prop, INDEX, custom={'hu': INDEX + ['hu_per_cap', 'hu_occ_prop']})
gprop.display()
# Out:
# age:
#    year    county  age_over18_prop  age_undr19_prop  age_undr19_gend_m_prop  \
# 0  2012     ADAMS         0.700040         0.299960                2.341611
# 1  2012   ALAMOSA         0.718650         0.281350                2.611540
# 2  2012  ARAPAHOE         0.725375         0.274625                2.828618
#
#    age_undr19_gend_f_prop  age_over18_gend_m_prop  age_over18_gend_f_prop  \
# 0                0.953744                2.003325                0.837159
# 1                0.928669                2.021878                0.754002
# 2                0.951183                2.070926                0.738717
#
#    age_median
# 0        32.4
# 1        32.2
# 2        35.7
# gend:
#    year    county  gend_m_prop  gend_f_prop  gend_m_age_undr19_prop  \
# 0  2012     ADAMS     2.104797     0.872130                0.333709
# 1  2012   ALAMOSA     2.187780     0.803145                0.335846
# 2  2012  ARAPAHOE     2.279007     0.797066                0.340854
#
#    gend_m_age_over18_prop  gend_f_age_undr19_prop  gend_f_age_over18_prop
# 0                0.666291                0.328030                0.671970
# 1                0.664154                0.325322                0.674678
# 2                0.659146                0.327725                0.672275
# race:
#    year    county  race_hispanic_prop  race_white_prop  race_black_prop  \
# 0  2012     ADAMS            0.723562         1.019087         0.056009
# 1  2012   ALAMOSA            0.918446         0.992842         0.014061
# 2  2012  ARAPAHOE            0.359510         1.246859         0.190153
#
#    race_asian_prop  race_other_prop  race_prop_stdev
# 0         0.066088         0.048257         0.409877
# 1         0.007542         0.080404         0.452841
# 2         0.095940         0.070829         0.438949
# inc:
#    year    county  inc_per_cap  inc_hh_median
# 0  2012     ADAMS      24357.0        56633.0
# 1  2012   ALAMOSA      19657.0        38045.0
# 2  2012  ARAPAHOE      32845.0        60400.0
# hh:
#    year    county  hh_size_avg
# 0  2012     ADAMS         2.91
# 1  2012   ALAMOSA         2.49
# 2  2012  ARAPAHOE         2.55
# citz:
#    year    county  citz_birth_prop  citz_co_prop  citz_per_cap
# 0  2012     ADAMS         0.950229      0.565176      1.710801
# 1  2012   ALAMOSA         0.983203      0.631001      1.933018
# 2  2012  ARAPAHOE         0.937754      0.429728      1.777281
# hsgrad:
#    year    county  hsgrad_graduated_prop
# 0  2012     ADAMS               0.604913
# 1  2012   ALAMOSA               0.630942
# 2  2012  ARAPAHOE               0.525874
# civ_lf:
#    year    county  civ_lf_prop  civ_lf_employed_prop
# 0  2012     ADAMS     1.019601              0.905485
# 1  2012   ALAMOSA     0.916656              0.899317
# 2  2012  ARAPAHOE     1.087141              0.918400
# ps:
#    year    county  ps_total_prop  ps_undr18_total_prop  ps_undr18_prop
# 0  2012     ADAMS       0.141516              0.203240        0.407657
# 1  2012   ALAMOSA       0.218233              0.198585        0.237543
# 2  2012  ARAPAHOE       0.117654              0.159459        0.344372
# stud:
#    year    county  stud_enrolled_prop  stud_hs_prop  stud_undergrad_prop
# 0  2012     ADAMS            0.279257      0.305236             0.164248
# 1  2012   ALAMOSA            0.359793      0.366708             0.426147
# 2  2012  ARAPAHOE            0.279887      0.340967             0.191012
# hu:
#    year    county  hu_per_cap  hu_occ_prop
# 0  2012     ADAMS    0.704946     0.925198
# 1  2012   ALAMOSA    0.840087     0.890596
# 2  2012  ARAPAHOE    0.814089     0.939482
# hu_blt:
#    year    county  hu_blt_2000_plus_prop  hu_blt_lt_1950_prop  \
# 0  2012     ADAMS               0.236957             0.037722
# 1  2012   ALAMOSA               0.098904             0.233719
# 2  2012  ARAPAHOE               0.165498             0.030085
#
#    hu_blt_1950_1959_prop  hu_blt_1960_1969_prop  hu_blt_1970_1979_prop  \
# 0               0.124776               0.120157               0.184906
# 1               0.089927               0.099513               0.213786
# 2               0.069361               0.093458               0.261392
#
#    hu_blt_1980_1989_prop  hu_blt_1990_1999_prop  hu_blt_freq_yr_ord  \
# 0               0.124770               0.169059                   7
# 1               0.131163               0.131771                   1
# 2               0.235182               0.142715                   4
#
#   hu_blt_freq_yr
# 0     b2000_2009
# 1        b1949_e
# 2     b1970_1979
# hu_oo:
#    year    county  hu_oo_prop  hu_oo_lt_50_prop  hu_oo_50_150_prop  \
# 0  2012     ADAMS    0.662818          0.085687           0.198166
# 1  2012   ALAMOSA    0.632496          0.117504           0.431929
# 2  2012  ARAPAHOE    0.639821          0.029387           0.154892
#
#    hu_oo_150_250_prop  hu_oo_250_400_prop  hu_oo_400_750_prop  \
# 0            0.475317            0.177598            0.054211
# 1            0.290924            0.107239            0.047812
# 2            0.390722            0.266929            0.114133
#
#    hu_oo_750_plus_prop  hu_oo_freq_val_ord hu_oo_freq_val
# 0             0.009020                   3     v150k_250k
# 1             0.004592                   2      v50k_150k
# 2             0.043937                   3     v150k_250k

# %%
write_main(prop, 'county_stats_normalized')
write_main(counts, 'county_stats_counts')
write_main(df, 'county_stats')
# Out:
# 512

# %% [markdown]
# ---
# ---
# # `5-education`
#
# [BACK TO TOP ^](#top-of-page)
#
# ---
# ---

# %% [markdown]
# # Education data prep

# %% [markdown]
# ### This script combines the following 3 datasets, aggregates them by county, redesigns column naming structure, and re-calculates rates:
# 1. District Student Mobility/Stability Statistics 2011-2012 **by Instructional Program/Service Type**
# 2. District Student Mobility/Stability Statistics 2011-2012 **by Gender & Race/Ethnicity**
# 3. District Graduation Data Statistics 2011-2012 **by Instructional Program Service Type**
# ## Reference: Column Naming conventions
#
# - This dataset is designed so you should never have to look at the columns to find the name of one (since there are around 140 columns). Just look here for reference instead.
# - For instance, to get the rate for any variable, just use `_rate` after a variable. So `graduated` becomes `graduated_rate`
#
# | Type | Naming | Example |
# | - | - | - |
# | County Total | variable | `stable` |
# | Count | group + variable | `disabled_stable` |
# | Rate | group + variable + "rate" | `disabled_stable_rate` |
# | Group Total | group + group total | `disabled_pupil_total` |
#
# <br>
#
# #### Mobility/Stability columns
#
# | GROUPS | VARIABLES | GROUP TOTALS |
# | - | - | - |
# | disabled | stable | pupil_total |
# | limited_eng | mobile |
# | poor | mobile_instances |
# | migrant |
# | title_1 |
# | homeless |
# | gifted |
# | male |
# | female |
# | white |
# | asian |
# | black |
# | hispanic |
#
# <br>
#
# #### Graduation columns
#
# | GROUPS | VARIABLES | GROUP TOTALS |
# | - | - | - |
# | disabled | graduated | grad_base_total |
# | limited_eng | completed |
# | poor |
# | migrant |
# | title_1 |
# | homeless |
# | gifted |
#
# <br>
#
# **What are group totals?**
# - Notice they aren't just called "total". This is because, for graduation data, we don't care about the total number of students. We care about the total number of students who are actually in the pool for graduation. So, we call it `grad_base_total` and use that when calculating rate
#
# **Rates are calculated by dividing a variable by its group total, then multiplying by 100**

# %% [markdown]
# ---
# ---
# ---

# %%
filtr = "`Organization Name` != 'STATE TOTAL'"

grad_raw = read_raw('dist_grad_rate', WHERE=filtr)
mob_raw = read_raw('dist_student_mobility', WHERE=filtr)
mob_dem_raw = read_raw('dist_mobility_demographics', WHERE=filtr)

head(grad_raw, mob_raw, mob_dem_raw)
# Out:
# 38 cols x 183 rows
#   County Name  Organization Code           Organization Name  \
# 0       ADAMS                 10                  MAPLETON 1
# 1       ADAMS                 20  ADAMS 12 FIVE STAR SCHOOLS
# 2       ADAMS                 30             ADAMS COUNTY 14
#
#    Students with Disabilities Final Grad Base  \
# 0                                          49
# 1                                         250
# 2                                          59
#
#    Students with Disabilities Graduates Total  \
# 0                                          18
# 1                                         118
# 2                                          32
#
#    Students with Disabilities Graduation Rate  \
# 0                                        36.7
# 1                                        47.2
# 2                                        54.2
#
#    Students with Disabilities Completers Total  \
# 0                                           19
# 1                                          127
# 2                                           32
#
#    Students with Disabilities Completion Rate  \
# 0                                        38.8
# 1                                        50.8
# 2                                        54.2
#
#    Limited English Proficient Final Grad Base  \
# 0                                         219
# 1                                         379
# 2                                         170
#
#    Limited English Proficient Graduates Total  ...  Homeless Final Grad Base  \
# 0                                          73  ...                        41
# 1                                         257  ...                       106
# 2                                          86  ...                        99
#
#    Homeless Graduates Total  Homeless Graduation Rate  \
# 0                        12                      29.3
# 1                        62                      58.5
# 2                        52                      52.5
#
#    Homeless Completers Total  Homeless Completion Rate  \
# 0                         16                      39.0
# 1                         65                      61.3
# 2                         57                      57.6
#
#    Gifted-Talented Final Grad Base  Gifted-Talented Graduates Total  \
# 0                               44                               27
# 1                              227                              201
# 2                               30                               27
#
#    Gifted-Talented Graduation Rate  Gifted-Talented Completers Total  \
# 0                             61.4                                27
# 1                             88.5                               208
# 2                             90.0                                27
#
#    Gifted-Talented Completion Rate
# 0                             61.4
# 1                             91.6
# 2                             90.0
#
# [3 rows x 38 columns]
# 60 cols x 183 rows
#    School Year  Org. Code           Organization Name  \
# 0     20112012         10                  MAPLETON 1
# 1     20112012         20  ADAMS 12 FIVE STAR SCHOOLS
# 2     20112012         30             ADAMS COUNTY 14
#
#                                            Category  \
# 0  1DISTRICT TOTALS (INCLUDING ALTERNATIVE SCHOOLS)
# 1  1DISTRICT TOTALS (INCLUDING ALTERNATIVE SCHOOLS)
# 2  1DISTRICT TOTALS (INCLUDING ALTERNATIVE SCHOOLS)
#
#    Total Pupil Count (All students)  Total Stable Pupil Count (All Students)  \
# 0                              9037                                     5077
# 1                             49889                                    34283
# 2                              8265                                     5510
#
#    Total Stability Rate (All Students)  \
# 0                                 56.2
# 1                                 68.7
# 2                                 66.7
#
#    Total Mobile Student Count (All students)  \
# 0                                       3919
# 1                                      15424
# 2                                       3038
#
#    Total Student Mobility Rate (All students)  \
# 0                                        43.4
# 1                                        30.9
# 2                                        36.8
#
#    Total Instances of Mobility (All students)  ...  \
# 0                                        4133  ...
# 1                                       16854  ...
# 2                                        3397  ...
#
#    Homeless Student Mobility Rate  Homeless Instances of Mobility  \
# 0                            32.7                              79
# 1                            57.2                             481
# 2                            49.7                             529
#
#    Homeless Mobility Incidence Rate  Gifted & Talented Pupil Count  \
# 0                              36.9                            250
# 1                              68.2                           3590
# 2                              59.7                            377
#
#    Gifted & Talented Stable Student Count  Gifted & Talented Stability Rate  \
# 0                                     205                              82.0
# 1                                    3225                              89.8
# 2                                     317                              84.1
#
#    Gifted & Talented Mobile Student Count  \
# 0                                      44
# 1                                     361
# 2                                      75
#
#    Gifted & Talented Student Mobility Rate  \
# 0                                     17.6
# 1                                     10.1
# 2                                     19.9
#
#    Gifted & Talented Instances of Mobility  \
# 0                                       47
# 1                                      404
# 2                                       89
#
#    Gifted & Talented Mobility Incidence Rate
# 0                                       18.8
# 1                                       11.3
# 2                                       23.6
#
# [3 rows x 60 columns]
# 74 cols x 183 rows
#    School Year  Org. Code           Organization Name  \
# 0     20112012         10                  MAPLETON 1
# 1     20112012         20  ADAMS 12 FIVE STAR SCHOOLS
# 2     20112012         30             ADAMS COUNTY 14
#
#                                            Category  Total Pupil Count  \
# 0  1DISTRICT TOTALS (INCLUDING ALTERNATIVE SCHOOLS)               9037
# 1  1DISTRICT TOTALS (INCLUDING ALTERNATIVE SCHOOLS)              49889
# 2  1DISTRICT TOTALS (INCLUDING ALTERNATIVE SCHOOLS)               8265
#
#    Total Stable Student Count  Total Stability Rate  \
# 0                        5077                  56.2
# 1                       34283                  68.7
# 2                        5510                  66.7
#
#    Total Mobile Student Count  Total Student Mobility Rate  \
# 0                        3919                         43.4
# 1                       15424                         30.9
# 2                        3038                         36.8
#
#    Total Instances Of Mobility  ...  \
# 0                         4133  ...
# 1                        16854  ...
# 2                         3397  ...
#
#    Total Native Hawaiian or Other Pacific Islander Student Mobility Rate  \
# 0                                               70.8
# 1                                               45.3
# 2                                                0.0
#
#    Total Native Hawaiian or Other Pacific Islander Instances Of Mobility  \
# 0                                                 17
# 1                                                 42
# 2                                                  0
#
#    Total Native Hawaiian or Other Pacific Islander Mobility Incidence Rate  \
# 0                                               70.8
# 1                                               48.8
# 2                                                0.0
#
#    Total Two or More Races Pupil Count  \
# 0                                  219
# 1                                  662
# 2                                   55
#
#    Total Two or More Races Stable Student Count  \
# 0                                           129
# 1                                           455
# 2                                            28
#
#    Total Two or More Races Stability Rate  \
# 0                                    58.9
# 1                                    68.7
# 2                                    50.9
#
#    Total Two or More Races Mobile Student Count  \
# 0                                            90
# 1                                           203
# 2                                            26
#
#    Total Two or More Races Student Mobility Rate  \
# 0                                           41.1
# 1                                           30.7
# 2                                           47.3
#
#    Total Two or More Races Instances Of Mobility  \
# 0                                             91
# 1                                            222
# 2                                             28
#
#    Total Two or More Races Mobility Incidence Rate
# 0                                             41.6
# 1                                             33.5
# 2                                             50.9
#
# [3 rows x 74 columns]

# %%
def format_cols(df):
    df = (df
        .drop_cols('County Name', 'Organization Code', 'School Year', 'Org. Code', 'Category')
        .rename_col('Organization Name', 'district')
        .rename(columns={c: re.sub(r"\s|-", "_", c.lower()) for c in df.columns})
    )
    df = df.rename(columns={c: re.sub(r"\.|\(|\)|\&", "", c).replace('__', '_') for c in df.columns})
    return df

grad_raw = format_cols(grad_raw)
mob_raw = format_cols(mob_raw)
mob_dem_raw = format_cols(mob_dem_raw)
head(grad_raw)
# Out:
# 36 cols x 183 rows
#                      district  students_with_disabilities_final_grad_base  \
# 0                  MAPLETON 1                                          49
# 1  ADAMS 12 FIVE STAR SCHOOLS                                         250
# 2             ADAMS COUNTY 14                                          59
#
#    students_with_disabilities_graduates_total  \
# 0                                          18
# 1                                         118
# 2                                          32
#
#    students_with_disabilities_graduation_rate  \
# 0                                        36.7
# 1                                        47.2
# 2                                        54.2
#
#    students_with_disabilities_completers_total  \
# 0                                           19
# 1                                          127
# 2                                           32
#
#    students_with_disabilities_completion_rate  \
# 0                                        38.8
# 1                                        50.8
# 2                                        54.2
#
#    limited_english_proficient_final_grad_base  \
# 0                                         219
# 1                                         379
# 2                                         170
#
#    limited_english_proficient_graduates_total  \
# 0                                          73
# 1                                         257
# 2                                          86
#
#    limited_english_proficient_graduation_rate  \
# 0                                        33.3
# 1                                        67.8
# 2                                        50.6
#
#    limited_english_proficient_completers_total  ...  homeless_final_grad_base  \
# 0                                           76  ...                        41
# 1                                          261  ...                       106
# 2                                           88  ...                        99
#
#    homeless_graduates_total  homeless_graduation_rate  \
# 0                        12                      29.3
# 1                        62                      58.5
# 2                        52                      52.5
#
#    homeless_completers_total  homeless_completion_rate  \
# 0                         16                      39.0
# 1                         65                      61.3
# 2                         57                      57.6
#
#    gifted_talented_final_grad_base  gifted_talented_graduates_total  \
# 0                               44                               27
# 1                              227                              201
# 2                               30                               27
#
#    gifted_talented_graduation_rate  gifted_talented_completers_total  \
# 0                             61.4                                27
# 1                             88.5                               208
# 2                             90.0                                27
#
#    gifted_talented_completion_rate
# 0                             61.4
# 1                             91.6
# 2                             90.0
#
# [3 rows x 36 columns]

# %% [markdown]
# ### Before joining, make sure all district columns match

# %%
sorted(grad_raw.district) == sorted(mob_raw.district) == sorted(mob_dem_raw.district)
# Out:
# True

# %% [markdown]
# ### Merge

# %%
# Remove the columns duplicated across mobility demographics and mobility datasets
mob_dem = mob_dem_raw.drop_cols(
    'total_pupil_count', 'total_stable_student_count', 'total_stability_rate', 'total_mobile_student_count',
    'total_student_mobility_rate', 'total_instances_of_mobility', 'total_mobility_incidence_rate'
)

# Combine the two mobility datasets
df_raw_dist = (
    mob_raw
    .merge(mob_dem, on=['district'])
    .merge(grad_raw, on=['district'])
)
head(df_raw_dist)
# Out:
# 155 cols x 183 rows
#                      district  total_pupil_count_all_students  \
# 0                  MAPLETON 1                            9037
# 1  ADAMS 12 FIVE STAR SCHOOLS                           49889
# 2             ADAMS COUNTY 14                            8265
#
#    total_stable_pupil_count_all_students  total_stability_rate_all_students  \
# 0                                   5077                               56.2
# 1                                  34283                               68.7
# 2                                   5510                               66.7
#
#    total_mobile_student_count_all_students  \
# 0                                     3919
# 1                                    15424
# 2                                     3038
#
#    total_student_mobility_rate_all_students  \
# 0                                      43.4
# 1                                      30.9
# 2                                      36.8
#
#    total_instances_of_mobility_all_students  \
# 0                                      4133
# 1                                     16854
# 2                                      3397
#
#    total_mobility_incidence_rate_all_students  \
# 0                                        45.7
# 1                                        33.8
# 2                                        41.1
#
#    students_with_disabilities_pupil_count  \
# 0                                     735
# 1                                    4339
# 2                                     876
#
#    students_with_disabilities_stable_student_count  ...  \
# 0                                              469  ...
# 1                                             3001  ...
# 2                                              636  ...
#
#    homeless_final_grad_base  homeless_graduates_total  \
# 0                        41                        12
# 1                       106                        62
# 2                        99                        52
#
#    homeless_graduation_rate  homeless_completers_total  \
# 0                      29.3                         16
# 1                      58.5                         65
# 2                      52.5                         57
#
#    homeless_completion_rate  gifted_talented_final_grad_base  \
# 0                      39.0                               44
# 1                      61.3                              227
# 2                      57.6                               30
#
#    gifted_talented_graduates_total  gifted_talented_graduation_rate  \
# 0                               27                             61.4
# 1                              201                             88.5
# 2                               27                             90.0
#
#    gifted_talented_completers_total  gifted_talented_completion_rate
# 0                                27                             61.4
# 1                               208                             91.6
# 2                                27                             90.0
#
# [3 rows x 155 columns]

# %% [markdown]
# ## Column Name Manipulation
# ---

# %%
df = df_raw_dist.copy()

# %% [markdown]
# ## Filter out columns based on substrings
# 1. Remove all rates. They got messed up when we aggregated by county
# 2. Remove native american and native hawaiian because the group sizes are very small and values are 0 for a lot of counties.
# 3. Remove "two_or_more_races" because it's inconsistent, and difficult to compare groups

# %%
df = (df
    .separate_by("rate", mode='exclude')
    .separate_by("american_indian", mode='exclude')
    .separate_by("native_hawaiian", mode='exclude')
    .separate_by("two_or_more", mode='exclude')
)

# %% [markdown]
# ### Standardize group names, then shorten group names
# - Graduation data has `limited_english_proficient` and `econ_disadvant`
# - Mobility data `english_language_learners` and `economically_disadvantaged`
#
# **Standardize these to `limited_english` and `econ_disadvant`, and shorten the others**

# %%
df = (df
    .col_replace({
        # Mobility/Stability groups
        "limited_english_proficient": "limited_eng",
        "english_language_learners": "limited_eng",
        "economically_disadvantaged": "poor",
        "econ_disadvant": "poor",
        "students_with_disabilities": "disabled",
        "gifted_talented": "gifted",
        # Demographics
        "black_or_african_american": "black",
        "hispanic_or_latino": "hispanic",
        # Graduation data
        "final_grad_base": "grad_base_total",
        "graduates_total": "graduated",
        "completers_total": "completed",
        # Mobility/Stability data
        "instances_of_mobility": "mobile_instances",
        "pupil_count": "pupil_total",
        "_student_count": "",
        # Variable totals
        "_all_students": "",
        "total_": "",
    })
    .rename_col('stable_pupil_total', 'stable')
)
df_dist_counts = df
head(df_dist_counts, with_tail=True)
# Out:
# 78 cols x 183 rows
#                        district  pupil_total  stable  mobile  \
# 0                    MAPLETON 1         9037    5077    3919
# 1    ADAMS 12 FIVE STAR SCHOOLS        49889   34283   15424
# 181              SAN JUAN BOCES           84       0      84
# 182         EXPEDITIONARY BOCES          402     302     100
#
#      mobile_instances  disabled_pupil_total  disabled_stable  disabled_mobile  \
# 0                4133                   735              469              261
# 1               16854                  4339             3001             1325
# 181                84                     5                0                5
# 182               101                    40               34                6
#
#      disabled_mobile_instances  limited_eng_pupil_total  ...  \
# 0                          279                     2863  ...
# 1                         1501                     6141  ...
# 181                          5                        0  ...
# 182                          6                       16  ...
#
#      migrant_completed  title_1_grad_base_total  title_1_graduated  \
# 0                    5                      218                118
# 1                   12                      224                 80
# 181                  0                        0                  0
# 182                  0                        0                  0
#
#      title_1_completed  homeless_grad_base_total  homeless_graduated  \
# 0                  124                        41                  12
# 1                   98                       106                  62
# 181                  0                         0                   0
# 182                  0                         0                   0
#
#      homeless_completed  gifted_grad_base_total  gifted_graduated  \
# 0                    16                      44                27
# 1                    65                     227               201
# 181                   0                       1                 0
# 182                   0                       0                 0
#
#      gifted_completed
# 0                  27
# 1                 208
# 181                 1
# 182                 0
#
# [4 rows x 78 columns]

# %% [markdown]
# #### Standardize district names

# %%
# standardize_district_name defined in workspace setup
df.district = df.district.apply(standardize_district_name)
head(df)
# Out:
# 78 cols x 183 rows
#            district  pupil_total  stable  mobile  mobile_instances  \
# 0        MAPLETON 1         9037    5077    3919              4133
# 1  ADAMSFIVESTAR 12        49889   34283   15424             16854
# 2    ADAMSCOUNTY 14         8265    5510    3038              3397
#
#    disabled_pupil_total  disabled_stable  disabled_mobile  \
# 0                   735              469              261
# 1                  4339             3001             1325
# 2                   876              636              266
#
#    disabled_mobile_instances  limited_eng_pupil_total  ...  migrant_completed  \
# 0                        279                     2863  ...                  5
# 1                       1501                     6141  ...                 12
# 2                        311                     3826  ...                  4
#
#    title_1_grad_base_total  title_1_graduated  title_1_completed  \
# 0                      218                118                124
# 1                      224                 80                 98
# 2                      419                296                301
#
#    homeless_grad_base_total  homeless_graduated  homeless_completed  \
# 0                        41                  12                  16
# 1                       106                  62                  65
# 2                        99                  52                  57
#
#    gifted_grad_base_total  gifted_graduated  gifted_completed
# 0                      44                27                27
# 1                     227               201               208
# 2                      30                27                27
#
# [3 rows x 78 columns]

# %%
write_main(df_dist_counts, 'education_dist_counts')
# Out:
# 183

# %% [markdown]
# #### Bring in county column

# %%
dist_county = read_main('select district, in_county as county from district')
head(dist_county)
# Out:
# 2 cols x 183 rows
#            district county
# 0        MAPLETON 1  ADAMS
# 1  ADAMSFIVESTAR 12  ADAMS
# 2    ADAMSCOUNTY 14  ADAMS

# %% [markdown]
# #### Make sure all districts match across datasets

# %%
# join_conflicts defined in workspace setup
conflicts = join_conflicts(df, dist_county, 'district')
assert len(conflicts) == 0

df = df.merge(dist_county, on='district').move_col('county', 1)
head(df)
# Out:
# 79 cols x 183 rows
#            district county  pupil_total  stable  mobile  mobile_instances  \
# 0        MAPLETON 1  ADAMS         9037    5077    3919              4133
# 1  ADAMSFIVESTAR 12  ADAMS        49889   34283   15424             16854
# 2    ADAMSCOUNTY 14  ADAMS         8265    5510    3038              3397
#
#    disabled_pupil_total  disabled_stable  disabled_mobile  \
# 0                   735              469              261
# 1                  4339             3001             1325
# 2                   876              636              266
#
#    disabled_mobile_instances  ...  migrant_completed  title_1_grad_base_total  \
# 0                        279  ...                  5                      218
# 1                       1501  ...                 12                      224
# 2                        311  ...                  4                      419
#
#    title_1_graduated  title_1_completed  homeless_grad_base_total  \
# 0                118                124                        41
# 1                 80                 98                       106
# 2                296                301                        99
#
#    homeless_graduated  homeless_completed  gifted_grad_base_total  \
# 0                  12                  16                      44
# 1                  62                  65                     227
# 2                  52                  57                      30
#
#    gifted_graduated  gifted_completed
# 0                27                27
# 1               201               208
# 2                27                27
#
# [3 rows x 79 columns]

# %% [markdown]
# ### Create county grouping

# %%
df_county_counts = (df
    .groupby(['county'])
    .sum(numeric_only=True)
    .reset_index()
)
head(df_county_counts)
# Out:
# 78 cols x 63 rows
#      county  pupil_total  stable  mobile  mobile_instances  \
# 0     ADAMS        98546   67272   31222             33925
# 1   ALAMOSA         2775    1882     885               950
# 2  ARAPAHOE       124639   94109   30134             32269
#
#    disabled_pupil_total  disabled_stable  disabled_mobile  \
# 0                  8848             6263             2588
# 1                   223              159               63
# 2                 11842             9461             2354
#
#    disabled_mobile_instances  limited_eng_pupil_total  ...  migrant_completed  \
# 0                       2896                    20773  ...                 33
# 1                         66                      368  ...                  4
# 2                       2568                    25370  ...                  9
#
#    title_1_grad_base_total  title_1_graduated  title_1_completed  \
# 0                      935                529                559
# 1                       28                 22                 23
# 2                      488                202                213
#
#    homeless_grad_base_total  homeless_graduated  homeless_completed  \
# 0                       360                 190                 204
# 1                         6                   6                   6
# 2                       243                  96                 102
#
#    gifted_grad_base_total  gifted_graduated  gifted_completed
# 0                     402               337               345
# 1                       0                 0                 0
# 2                     909               820               828
#
# [3 rows x 78 columns]

# %%
write_main(df_county_counts, 'education_county_counts')
# Out:
# 63

# %% [markdown]
# ## Calculate Rates
# ---

# %% [markdown]
# - This code is very confusing, but basically I'm just trying to dynamically divide each statistic by its parent's group total to get a percentage, and multiply by 100 to get a rate.
# - For example, `disabled_stable` / `stable` gets the percent of stable students who are disabled. Then, `stable` / `pupil_total` gets the percent of all students who are stable, and so on.

# %%
def get_rates(df, index):
    df = df.copy()
    df_rates = df.copy()[index]

    for c in ['stable', 'mobile', 'mobile_instances']:
        group_rate = (df[c] / df['pupil_total'] * 100).round(2).fillna(0)
        df_rates[f"{c}_rate"] = group_rate
        df[f"{c}_rate"] = group_rate

    # Calculate rates dynamically
    for group in [
            'disabled', 'limited_eng', 'poor', 'migrant', 'title_1', 'homeless', 'gifted',
            'male', 'female', 'white', 'black', 'hispanic', 'asian']:

        for c in [c for c in df.columns if group in c and "total" not in c]:
            var = c.replace(f"{group}_", '')

            if var in ['graduated', 'completed']:
                new = df[c] / df[f"{group}_grad_base_total"]
            else:
                new = df[c] / df[f"{group}_pupil_total"]
            
            new = (new * 100).round(2).fillna(0)
            df_rates[f"{c}_rate"] = new
            df[f"{c}_rate"] = new

    return df, df_rates

# %%
df_dist_all, df_dist_rates = get_rates(df_dist_counts, ['district'])
df_county_all, df_county_rates = get_rates(df_county_counts, ['county'])

# %%
head(df_dist_all, df_dist_counts, df_dist_rates, df_county_all, df_county_counts, df_county_rates)
# Out:
# 137 cols x 183 rows
#            district  pupil_total  stable  mobile  mobile_instances  \
# 0        MAPLETON 1         9037    5077    3919              4133
# 1  ADAMSFIVESTAR 12        49889   34283   15424             16854
# 2    ADAMSCOUNTY 14         8265    5510    3038              3397
#
#    disabled_pupil_total  disabled_stable  disabled_mobile  \
# 0                   735              469              261
# 1                  4339             3001             1325
# 2                   876              636              266
#
#    disabled_mobile_instances  limited_eng_pupil_total  ...  \
# 0                        279                     2863  ...
# 1                       1501                     6141  ...
# 2                        311                     3826  ...
#
#    white_mobile_instances_rate  black_stable_rate  black_mobile_rate  \
# 0                        52.08              48.04              51.40
# 1                        32.27              55.98              43.94
# 2                        47.45              48.20              51.80
#
#    black_mobile_instances_rate  hispanic_stable_rate  hispanic_mobile_rate  \
# 0                        53.63                 60.31                 39.19
# 1                        47.41                 67.30                 32.23
# 2                        53.60                 68.67                 35.20
#
#    hispanic_mobile_instances_rate  asian_stable_rate  asian_mobile_rate  \
# 0                           42.19              47.22              52.78
# 1                           36.81              81.07              18.84
# 2                           39.57              80.00              20.00
#
#    asian_mobile_instances_rate
# 0                        53.70
# 1                        21.15
# 2                        20.00
#
# [3 rows x 137 columns]
# 78 cols x 183 rows
#            district  pupil_total  stable  mobile  mobile_instances  \
# 0        MAPLETON 1         9037    5077    3919              4133
# 1  ADAMSFIVESTAR 12        49889   34283   15424             16854
# 2    ADAMSCOUNTY 14         8265    5510    3038              3397
#
#    disabled_pupil_total  disabled_stable  disabled_mobile  \
# 0                   735              469              261
# 1                  4339             3001             1325
# 2                   876              636              266
#
#    disabled_mobile_instances  limited_eng_pupil_total  ...  migrant_completed  \
# 0                        279                     2863  ...                  5
# 1                       1501                     6141  ...                 12
# 2                        311                     3826  ...                  4
#
#    title_1_grad_base_total  title_1_graduated  title_1_completed  \
# 0                      218                118                124
# 1                      224                 80                 98
# 2                      419                296                301
#
#    homeless_grad_base_total  homeless_graduated  homeless_completed  \
# 0                        41                  12                  16
# 1                       106                  62                  65
# 2                        99                  52                  57
#
#    gifted_grad_base_total  gifted_graduated  gifted_completed
# 0                      44                27                27
# 1                     227               201               208
# 2                      30                27                27
#
# [3 rows x 78 columns]
# 60 cols x 183 rows
#            district  stable_rate  mobile_rate  mobile_instances_rate  \
# 0        MAPLETON 1        56.18        43.37                  45.73
# 1  ADAMSFIVESTAR 12        68.72        30.92                  33.78
# 2    ADAMSCOUNTY 14        66.67        36.76                  41.10
#
#    disabled_stable_rate  disabled_mobile_rate  disabled_mobile_instances_rate  \
# 0                 63.81                 35.51                           37.96
# 1                 69.16                 30.54                           34.59
# 2                 72.60                 30.37                           35.50
#
#    disabled_graduated_rate  disabled_completed_rate  limited_eng_stable_rate  \
# 0                    36.73                    38.78                    66.01
# 1                    47.20                    50.80                    67.56
# 2                    54.24                    54.24                    73.05
#
#    ...  white_mobile_instances_rate  black_stable_rate  black_mobile_rate  \
# 0  ...                        52.08              48.04              51.40
# 1  ...                        32.27              55.98              43.94
# 2  ...                        47.45              48.20              51.80
#
#    black_mobile_instances_rate  hispanic_stable_rate  hispanic_mobile_rate  \
# 0                        53.63                 60.31                 39.19
# 1                        47.41                 67.30                 32.23
# 2                        53.60                 68.67                 35.20
#
#    hispanic_mobile_instances_rate  asian_stable_rate  asian_mobile_rate  \
# 0                           42.19              47.22              52.78
# 1                           36.81              81.07              18.84
# 2                           39.57              80.00              20.00
#
#    asian_mobile_instances_rate
# 0                        53.70
# 1                        21.15
# 2                        20.00
#
# [3 rows x 60 columns]
# 137 cols x 63 rows
#      county  pupil_total  stable  mobile  mobile_instances  \
# 0     ADAMS        98546   67272   31222             33925
# 1   ALAMOSA         2775    1882     885               950
# 2  ARAPAHOE       124639   94109   30134             32269
#
#    disabled_pupil_total  disabled_stable  disabled_mobile  \
# 0                  8848             6263             2588
# 1                   223              159               63
# 2                 11842             9461             2354
#
#    disabled_mobile_instances  limited_eng_pupil_total  ...  \
# 0                       2896                    20773  ...
# 1                         66                      368  ...
# 2                       2568                    25370  ...
#
#    white_mobile_instances_rate  black_stable_rate  black_mobile_rate  \
# 0                        32.45              54.66              45.08
# 1                        35.54              57.14              42.86
# 2                        21.16              67.47              32.03
#
#    black_mobile_instances_rate  hispanic_stable_rate  hispanic_mobile_rate  \
# 0                        47.91                 67.49                 32.71
# 1                        42.86                 70.15                 29.47
# 2                        34.57                 72.76                 26.75
#
#    hispanic_mobile_instances_rate  asian_stable_rate  asian_mobile_rate  \
# 0                           36.40              78.55              21.37
# 1                           32.69              64.00              36.00
# 2                           29.20              78.59              21.30
#
#    asian_mobile_instances_rate
# 0                        23.54
# 1                        36.00
# 2                        22.56
#
# [3 rows x 137 columns]
# 78 cols x 63 rows
#      county  pupil_total  stable  mobile  mobile_instances  \
# 0     ADAMS        98546   67272   31222             33925
# 1   ALAMOSA         2775    1882     885               950
# 2  ARAPAHOE       124639   94109   30134             32269
#
#    disabled_pupil_total  disabled_stable  disabled_mobile  \
# 0                  8848             6263             2588
# 1                   223              159               63
# 2                 11842             9461             2354
#
#    disabled_mobile_instances  limited_eng_pupil_total  ...  migrant_completed  \
# 0                       2896                    20773  ...                 33
# 1                         66                      368  ...                  4
# 2                       2568                    25370  ...                  9
#
#    title_1_grad_base_total  title_1_graduated  title_1_completed  \
# 0                      935                529                559
# 1                       28                 22                 23
# 2                      488                202                213
#
#    homeless_grad_base_total  homeless_graduated  homeless_completed  \
# 0                       360                 190                 204
# 1                         6                   6                   6
# 2                       243                  96                 102
#
#    gifted_grad_base_total  gifted_graduated  gifted_completed
# 0                     402               337               345
# 1                       0                 0                 0
# 2                     909               820               828
#
# [3 rows x 78 columns]
# 60 cols x 63 rows
#      county  stable_rate  mobile_rate  mobile_instances_rate  \
# 0     ADAMS        68.26        31.68                  34.43
# 1   ALAMOSA        67.82        31.89                  34.23
# 2  ARAPAHOE        75.51        24.18                  25.89
#
#    disabled_stable_rate  disabled_mobile_rate  disabled_mobile_instances_rate  \
# 0                 70.78                 29.25                           32.73
# 1                 71.30                 28.25                           29.60
# 2                 79.89                 19.88                           21.69
#
#    disabled_graduated_rate  disabled_completed_rate  limited_eng_stable_rate  \
# 0                    47.54                    50.10                    69.99
# 1                    86.67                    93.33                    72.01
# 2                    51.26                    52.06                    74.94
#
#    ...  white_mobile_instances_rate  black_stable_rate  black_mobile_rate  \
# 0  ...                        32.45              54.66              45.08
# 1  ...                        35.54              57.14              42.86
# 2  ...                        21.16              67.47              32.03
#
#    black_mobile_instances_rate  hispanic_stable_rate  hispanic_mobile_rate  \
# 0                        47.91                 67.49                 32.71
# 1                        42.86                 70.15                 29.47
# 2                        34.57                 72.76                 26.75
#
#    hispanic_mobile_instances_rate  asian_stable_rate  asian_mobile_rate  \
# 0                           36.40              78.55              21.37
# 1                           32.69              64.00              36.00
# 2                           29.20              78.59              21.30
#
#    asian_mobile_instances_rate
# 0                        23.54
# 1                        36.00
# 2                        22.56
#
# [3 rows x 60 columns]

# %% [markdown]
# ## Save
# ---

# %%
write_main(df_dist_all, 'education_dist')
write_main(df_dist_rates, 'education_dist_rates')

write_main(df_county_all, 'education_county')
write_main(df_county_rates, 'education_county_rates')
# Out:
# 63

# %% [markdown]
# ---
# ---
# # `6-crime`
#
# [BACK TO TOP ^](#top-of-page)
#
# ---
# ---

# %% [markdown]
# # Crime data prep
# ---
# - Cleaning records from source
# - Refactoring
# - Standardizing county names
# - Generating new columns based on date (day of week, quarter, year)
# - Combining the 97-15 data and 16-19 data

# %% [markdown]
# ## Crime 16-19

# %%
head(read_raw('crime_16_19'))
# Out:
# 9 cols x 1851996 rows
#   pub_agency_name       county_name incident_date  incident_hour  \
# 0     Westminster  JEFFERSON; ADAMS    08/26/2017           17.0
# 1     Westminster  JEFFERSON; ADAMS    11/22/2017           20.0
# 2     Westminster  JEFFERSON; ADAMS    12/28/2017           21.0
#
#           offense_name crime_against offense_category_name offense_group  \
# 0   Aggravated Assault        Person      Assault Offenses             A
# 1   Aggravated Assault        Person      Assault Offenses             A
# 2  Motor Vehicle Theft      Property   Motor Vehicle Theft             A
#
#    age_num
# 0     52.0
# 1     29.0
# 2      NaN

# %%
df = read_raw("""
    NULL AS year,
    county_name AS county,
    pub_agency_name AS police_dept,
    incident_date AS date,
    NULL AS quarter,
    NULL AS month,
    NULL AS day_of_week,
    incident_hour AS hour,
    age_num AS age,
    crime_against,
    offense_name,
    offense_category_name AS offense_category
FROM crime_16_19
""")
head(df)
# Out:
# 12 cols x 1851996 rows
#    year            county  police_dept        date quarter month day_of_week  \
# 0  None  JEFFERSON; ADAMS  Westminster  08/26/2017    None  None        None
# 1  None  JEFFERSON; ADAMS  Westminster  11/22/2017    None  None        None
# 2  None  JEFFERSON; ADAMS  Westminster  12/28/2017    None  None        None
#
#    hour   age crime_against         offense_name     offense_category
# 0  17.0  52.0        Person   Aggravated Assault     Assault Offenses
# 1  20.0  29.0        Person   Aggravated Assault     Assault Offenses
# 2  21.0   NaN      Property  Motor Vehicle Theft  Motor Vehicle Theft

# %%
# Filter
df = df.loc[
    (~ df.police_dept.isin(['State Patrol', 'Colorado Bureau of Investigation'])) &
    (~ df.police_dept.isna())
]

df = df.copy() # This avoids setting on copy of a slice warning later

# Since we're focused on county and not police department, replace dual county
# police department county values (Ex: "JEFFERSON; ADAMS") with just the primary (Ex: "JEFFERSON")
df.county = (
    df.county
    .str.split('; ')
    .str[0]
    .str.upper()
)

# Convert to datetime and parse out date parts
df['date'] = pd.to_datetime(df.date, infer_datetime_format=True)

df.year = df.date.dt.year.copy()
df.quarter = df.date.dt.quarter.copy()
df.month = df.date.dt.month.copy()
df.day_of_week = df.date.dt.day_of_week.copy()

df_16_19 = df
head(df_16_19)
# Out:
# 12 cols x 1845650 rows
#    year     county  police_dept       date  quarter  month  day_of_week  hour  \
# 0  2017  JEFFERSON  Westminster 2017-08-26        3      8            5  17.0
# 1  2017  JEFFERSON  Westminster 2017-11-22        4     11            2  20.0
# 2  2017  JEFFERSON  Westminster 2017-12-28        4     12            3  21.0
#
#     age crime_against         offense_name     offense_category
# 0  52.0        Person   Aggravated Assault     Assault Offenses
# 1  29.0        Person   Aggravated Assault     Assault Offenses
# 2   NaN      Property  Motor Vehicle Theft  Motor Vehicle Theft

# %% [markdown]
# ## Crime 97-15

# %%
head(read_raw('crime_97_15'))
# Out:
# 10 cols x 4952282 rows
#                    agency_name agency_type_name  city_name primary_county  \
# 0      Lyons Police Department             City      Lyons        Boulder
# 1  Kremmling Police Department             City  Kremmling          Grand
# 2  Oak Creek Police Department             City  Oak Creek          Routt
#
#    incident_hour offense_name crime_against offense_category_name  age_num  \
# 0            NaN         None          None                  None      NaN
# 1            NaN         None          None                  None      NaN
# 2            NaN         None          None                  None      NaN
#
#   incident_date
# 0          None
# 1          None
# 2          None

# %%
df = read_raw("""
    NULL AS year,
    UPPER(primary_county) AS county,
    agency_name AS police_dept,
    incident_date AS date,
    NULL AS quarter,
    NULL AS month,
    NULL AS day_of_week,
    incident_hour AS hour,
    age_num AS age,
    crime_against,
    offense_name,
    offense_category_name AS offense_category
    """,
    FROM="crime_97_15"
)
head(df)
# Out:
# 12 cols x 4952282 rows
#    year   county                  police_dept  date quarter month day_of_week  \
# 0  None  BOULDER      Lyons Police Department  None    None  None        None
# 1  None    GRAND  Kremmling Police Department  None    None  None        None
# 2  None    ROUTT  Oak Creek Police Department  None    None  None        None
#
#    hour  age crime_against offense_name offense_category
# 0   NaN  NaN          None         None             None
# 1   NaN  NaN          None         None             None
# 2   NaN  NaN          None         None             None

# %%
# Filter
df = df.loc[
    (~ df.police_dept.isin(['State Patrol', 'Colorado Bureau of Investigation'])) &
    (~ df.date.isna())
]
df = df.copy() # This avoids setting on copy of a slice warning later

df.date = pd.to_datetime(df.date, infer_datetime_format=True)

df.year = df.date.dt.year
df.quarter = df.date.dt.quarter
df.month = df.date.dt.month
df.day_of_week = df.date.dt.day_of_week

df_97_15 = df
head(df_97_15)
# Out:
# 12 cols x 4925016 rows
#     year      county                         police_dept       date  quarter  \
# 24  1997     BOULDER          Longmont Police Department 1997-03-14        1
# 25  1997     BOULDER          Longmont Police Department 1997-07-02        3
# 26  1997  KIT CARSON  Kit Carson County Sheriff's Office 1997-01-20        1
#
#     month  day_of_week  hour   age crime_against    offense_name  \
# 24      3            4   NaN  15.0        Person        Fondling
# 25      7            2  21.0  14.0      Property           Arson
# 26      1            0  22.0  58.0        Person  Simple Assault
#
#     offense_category
# 24      Sex Offenses
# 25             Arson
# 26  Assault Offenses

# %% [markdown]
# ## Combine into single dataset
# ---

# %%
# columns must be the same before concat on axis 0
assert list(df_16_19.columns) == list(df_97_15.columns)
df_all = (
    pd.concat([df_97_15, df_16_19], axis=0)
    .drop_cols('police_dept')
    .reset_index(drop=True)
)
head(df_all)
# Out:
# 11 cols x 6770666 rows
#    year      county       date  quarter  month  day_of_week  hour   age  \
# 0  1997     BOULDER 1997-03-14        1      3            4   NaN  15.0
# 1  1997     BOULDER 1997-07-02        3      7            2  21.0  14.0
# 2  1997  KIT CARSON 1997-01-20        1      1            0  22.0  58.0
#
#   crime_against    offense_name  offense_category
# 0        Person        Fondling      Sex Offenses
# 1      Property           Arson             Arson
# 2        Person  Simple Assault  Assault Offenses

# %%
write_main(df_all, 'crime_records')
# Out:
# 6770666

# %% [markdown]
# ---
# ---
# ---

# %% [markdown]
# # Aggregating crime data
#
# `crime_agg_category.csv`: 32 columns (crime counts broken down by offense **category**)
#
# `crime_agg_name.csv`: 54 columns (crime counts broken down by offense **name**)
#
# ### Creates two aggregated datasets. Both include:
# - First, ALL values in `crime_against`, `offense_name`, and `offense_category` are first renamed to shorter alternatives in *snake_case*. This was done in preparation for dummifying those columns, to make for friendly column names.
# - Data is grouped by year and county, and include the following aggregated columns:
#   - Crime count
#   - Average age
#   - Mode quarter (which quarter had the most crimes?)
#   - Mode month (which month had the most crimes?)
#   - Mode day of week (mon-fri => 1-7)
#   - Mode hour of day (military time)
#   - The original `crime_against` column was dummified, and summed during aggregation, to show total crime counts for each:
#     - `against_person`
#     - `against_society`
#     - `against_property`
#     - `not_a_crime`
#
# #### Additional columns in `crime_agg_category` data:
# - The original `offense_category` column was dummified, and then summed during aggregation, showing total crime counts broken up by offense category
#
# #### Additional columns in `crime_agg_name` data:
# - The original `offense_name` column was dummified, and then summed during aggregation, showing total crime counts broken up by offense name.

# %%
df_raw = read_main('crime_records')
head(df_raw)
# Out:
# 11 cols x 6770666 rows
#    year      county                 date  quarter  month  day_of_week  hour  \
# 0  1997     BOULDER  1997-03-14 00:00:00        1      3            4   NaN
# 1  1997     BOULDER  1997-07-02 00:00:00        3      7            2  21.0
# 2  1997  KIT CARSON  1997-01-20 00:00:00        1      1            0  22.0
#
#     age crime_against    offense_name  offense_category
# 0  15.0        Person        Fondling      Sex Offenses
# 1  14.0      Property           Arson             Arson
# 2  58.0        Person  Simple Assault  Assault Offenses

# %% [markdown]
# #### Remap all values in categorical columns based on excel sheet
# - We created 3 tables by hand in excel to rename EACH value in offense_name, offense_category and crime_against. This needed to be done in order to create dummy columns with friendly names.

# %%
read_sht = lambda sheet: pd.read_excel('column_renaming.xlsx', sheet_name=sheet)

display( read_sht('offense_name'), read_sht('offense_category'), read_sht('crime_against'))
# Out:
#                                             OLD                         NEW
# 0                                Simple Assault              assault_simple
# 1                                  Intimidation                intimidation
# 2                                      Fondling                    fondling
# 3                                          Rape                        rape
# 4                                 Impersonation               impersonation
# 5                                       Robbery                     robbery
# 6                                         Arson                       arson
# 7      Destruction/Damage/Vandalism of Property             property_damage
# 8                      Theft From Motor Vehicle          theft_from_vehicle
# 9                  Burglary/Breaking & Entering                    burglary
# 10                           Aggravated Assault          assault_aggravated
# 11         Murder and Nonnegligent Manslaughter                      murder
# 12                    Drug Equipment Violations              drug_equipment
# 13                     Drug/Narcotic Violations               drug_narcotic
# 14                     Stolen Property Offenses             stolen_property
# 15                                  Shoplifting                 shoplifting
# 16                            All Other Larceny               other_larceny
# 17                                   Wire Fraud                  wire_fraud
# 18                          Theft From Building         theft_from_building
# 19   Credit Card/Automated Teller Machine Fraud   credit_card_machine_fraud
# 20                          Motor Vehicle Theft               vehicle_theft
# 21                              Purse-snatching                 purse_theft
# 22                       Counterfeiting/Forgery                     forgery
# 23      False Pretenses/Swindle/Confidence Game            lying_under_oath
# 24  Theft of Motor Vehicle Parts or Accessories          vehicle_part_theft
# 25                 Pornography/Obscene Material                        porn
# 26                        Weapon Law Violations                  weapon_law
# 27                                      Bribery                     bribery
# 28   Theft From Coin-Operated Machine or Device  theft_from_vending_machine
# 29                         Kidnapping/Abduction                  kidnapping
# 30                Sexual Assault With An Object     sex_assault_with_object
# 31                               Statutory Rape              rape_statutory
# 32                          Extortion/Blackmail                   extortion
# 33                               Pocket-picking              pocket_picking
# 34          Assisting or Promoting Prostitution      prostitution_assisting
# 35                                 Embezzlement                embezzlement
# 36                                       Sodomy                      sodomy
# 37                                 Prostitution                prostitution
# 38                                       Incest                      incest
# 39                         Justifiable Homicide        homicide_justifiable
# 40                       Negligent Manslaughter      manslaughter_negligent
# 41                                Welfare Fraud               fraud_welfare
#                                          OLD              NEW
# 0                           Assault Offenses          assault
# 1                               Sex Offenses      sex_offense
# 2                             Fraud Offenses            fraud
# 3                                    Robbery          robbery
# 4                                      Arson            arson
# 5   Destruction/Damage/Vandalism of Property  property_damage
# 6                     Larceny/Theft Offenses    larceny_theft
# 7               Burglary/Breaking & Entering         burglary
# 8                          Homicide Offenses         homicide
# 9                     Drug/Narcotic Offenses             drug
# 10                  Stolen Property Offenses  stolen_property
# 11                       Motor Vehicle Theft    vehicle_theft
# 12                    Counterfeiting/Forgery          forgery
# 13              Pornography/Obscene Material             porn
# 14                     Weapon Law Violations       weapon_law
# 15                                   Bribery          bribery
# 16                      Kidnapping/Abduction       kidnapping
# 17                       Extortion/Blackmail        extortion
# 18                     Prostitution Offenses     prostitution
# 19                              Embezzlement     embezzlement
#            OLD               NEW
# 0       Person    against_person
# 1     Property  against_property
# 2      Society   against_society
# 3  Not a Crime       not_a_crime

# %%
df_refactored = (df_raw.copy()
    .rename_vals_from_df("offense_name", read_sht("offense_name"))
    .rename_vals_from_df("offense_category", read_sht("offense_category"))
    .rename_vals_from_df("crime_against", read_sht("crime_against"))
)
head(df_refactored)
# Out:
# 11 cols x 6770666 rows
#    year      county                 date  quarter  month  day_of_week  hour  \
# 0  1997     BOULDER  1997-03-14 00:00:00        1      3            4   NaN
# 1  1997     BOULDER  1997-07-02 00:00:00        3      7            2  21.0
# 2  1997  KIT CARSON  1997-01-20 00:00:00        1      1            0  22.0
#
#     age     crime_against    offense_name offense_category
# 0  15.0    against_person        fondling      sex_offense
# 1  14.0  against_property           arson            arson
# 2  58.0    against_person  assault_simple          assault

# %% [markdown]
# ### Aggregated datasets
# 1. Version 1: includes crime_category dummy sums
# 2. Version 2: includes crime_name dummy sums

# %%
INDEX = ['year', 'county']
df = df_refactored.copy()

@Extend(pd.DataFrame)
def dummies_special(self, include:str, exclude:str) -> pd.DataFrame:
    return (
        pd.get_dummies(self,
            columns=['crime_against', include],
            prefix="", prefix_sep=""
        )
        .drop_cols(exclude, 'date', 'quarter', 'month', 'day_of_week', 'hour', 'age')
        .groupby(INDEX)
        .sum()
        .reset_index()
    )

dum_cat = df.dummies_special('offense_category', 'offense_name')
dum_name = df.dummies_special('offense_name', 'offense_category')

# %%
# Convert these to modes
mode_cols = ['quarter', 'month', 'day_of_week', 'hour']
df_modes = df[INDEX + mode_cols]

# pd.Series.mode() is tough. When there's multiple modes, the cell value
# becomes a np.ndarray. So there's mixed values... You can't even safely index
# it because sometimes those arrays are EMPTY :(
# I applied the following function to fix this.
def first_in_list(x):
    """ pd.Series.mode returns ndarray when multiple modes. Safely convert to float """
    if type(x) == np.ndarray:
        if x.size > 0:
            return float(x[0])
        return np.nan
    return float(x)

# df.applymap() is just like apply but instead of acting on an axis, it acts on each cell in df
df_modes = (df_modes
    .groupby(INDEX)
    .agg(pd.Series.mode)
    .applymap(first_in_list)
    .reset_index()
    .rename(columns={c: f'{c}_mode' for c in mode_cols})
)

head(df_modes)
# Out:
# 6 cols x 1397 rows
#    year    county  quarter_mode  month_mode  day_of_week_mode  hour_mode
# 0  1997     ADAMS           1.0         3.0               0.0       17.0
# 1  1997   ALAMOSA           3.0         8.0               5.0       18.0
# 2  1997  ARAPAHOE           3.0         8.0               4.0       18.0

# %%
# Convert count and average
df_count = (df
    [INDEX + ['date']]
    .groupby(INDEX)
    .count()
    .reset_index()
    .rename(columns={'date': 'cr_count'})
)
df_avg = (df
    [INDEX + ['age']]
    .groupby(INDEX)
    .mean()
    .reset_index()
    .rename(columns={'age': 'age_avg'})
)
head(df_count, df_avg)
# Out:
# 3 cols x 1397 rows
#    year    county  cr_count
# 0  1997     ADAMS     22947
# 1  1997   ALAMOSA       404
# 2  1997  ARAPAHOE     37555
# 3 cols x 1397 rows
#    year    county    age_avg
# 0  1997     ADAMS  24.582071
# 1  1997   ALAMOSA  27.098901
# 2  1997  ARAPAHOE  25.209156

# %% [markdown]
# #### Stitching everything together

# %%
# Numerical aggregations: counts, avgs, modes
df = (df_count
    .merge(df_avg, on=INDEX)
    .merge(df_modes, on=INDEX)
)
head(df)
# Out:
# 8 cols x 1397 rows
#    year    county  cr_count    age_avg  quarter_mode  month_mode  \
# 0  1997     ADAMS     22947  24.582071           1.0         3.0
# 1  1997   ALAMOSA       404  27.098901           3.0         8.0
# 2  1997  ARAPAHOE     37555  25.209156           3.0         8.0
#
#    day_of_week_mode  hour_mode
# 0               0.0       17.0
# 1               5.0       18.0
# 2               4.0       18.0

# %% [markdown]
# ### Bring in total county population by year. This will be needed to calculate proportions

# %%
pop = read_main("""
    year,
    county,
    total as pop
    """,
    FROM="county_population",
    WHERE="year >= 1997 AND year <= 2019"
)

head(pop)
# Out:
# 3 cols x 1472 rows
#    year    county       pop
# 0  1997     ADAMS  167740.0
# 1  1997   ALAMOSA    7173.0
# 2  1997  ARAPAHOE  225524.0

# %%
# Summed aggregations for dummies: 2 versions
def create_merged_version(df, dummy_df) -> pd.DataFrame:
    global pop
    return (df
        .merge(dummy_df, on=INDEX)
        .merge(pop, on=INDEX)
        .move_col('pop', 2)
    )
df_cat = create_merged_version(df, dum_cat)
df_name = create_merged_version(df, dum_name)
head(df_cat, df_name)
# Out:
# 33 cols x 1397 rows
#    year    county       pop  cr_count    age_avg  quarter_mode  month_mode  \
# 0  1997     ADAMS  167740.0     22947  24.582071           1.0         3.0
# 1  1997   ALAMOSA    7173.0       404  27.098901           3.0         8.0
# 2  1997  ARAPAHOE  225524.0     37555  25.209156           3.0         8.0
#
#    day_of_week_mode  hour_mode  against_person  ...  kidnapping  \
# 0               0.0       17.0            3047  ...          50
# 1               5.0       18.0             101  ...           0
# 2               4.0       18.0            4568  ...         249
#
#    larceny_theft  porn  property_damage  prostitution  robbery  sex_offense  \
# 0           8023     1             5467            14      189          316
# 1            165     0               73             0        0            9
# 2          14345     0             5856           198      238          434
#
#    stolen_property  vehicle_theft  weapon_law
# 0              245           1317         274
# 1                0              6           4
# 2              421           2537         695
#
# [3 rows x 33 columns]
# 55 cols x 1397 rows
#    year    county       pop  cr_count    age_avg  quarter_mode  month_mode  \
# 0  1997     ADAMS  167740.0     22947  24.582071           1.0         3.0
# 1  1997   ALAMOSA    7173.0       404  27.098901           3.0         8.0
# 2  1997  ARAPAHOE  225524.0     37555  25.209156           3.0         8.0
#
#    day_of_week_mode  hour_mode  against_person  ...  shoplifting  sodomy  \
# 0               0.0       17.0            3047  ...         1323       3
# 1               5.0       18.0             101  ...            0       0
# 2               4.0       18.0            4568  ...         4134       0
#
#    stolen_property  theft_from_building  theft_from_vehicle  \
# 0              245                 1232                1733
# 1                0                   14                   7
# 2              421                 2283                3867
#
#    theft_from_vending_machine  vehicle_part_theft  vehicle_theft  weapon_law  \
# 0                          53                1293           1317         274
# 1                          10                   1              6           4
# 2                          72                 677           2537         695
#
#    wire_fraud
# 0           0
# 1           1
# 2           2
#
# [3 rows x 55 columns]

# %%
INDEX = ['year', 'county']

BASE_COLS = ['pop', 'cr_count', 'age_avg', 'quarter_mode', 'month_mode', 'day_of_week_mode', 'hour_mode', 'against_person', 'against_property', 'against_society', 'not_a_crime']

df_base = (df_cat
    .copy()
    [INDEX + BASE_COLS]
    .insert_at(5, 'cr_rate', df_cat.cr_count / df_cat['pop'] * 100_000)
)
for i in ['against_person', 'against_property', 'against_society']:
    df_base[f'{i}_rate'] = df_base[i] / df_base['pop'] * 100_000

df_cat = df_cat.drop(columns=BASE_COLS)
df_name = df_name.drop(columns=BASE_COLS)

head(df_base, df_cat, df_name)
# Out:
# 17 cols x 1397 rows
#    year    county       pop  cr_count    age_avg       cr_rate  quarter_mode  \
# 0  1997     ADAMS  167740.0     22947  24.582071  13680.100155           1.0
# 1  1997   ALAMOSA    7173.0       404  27.098901   5632.231981           3.0
# 2  1997  ARAPAHOE  225524.0     37555  25.209156  16652.329686           3.0
#
#    month_mode  day_of_week_mode  hour_mode  against_person  against_property  \
# 0         3.0               0.0       17.0            3047             17766
# 1         8.0               5.0       18.0             101               264
# 2         8.0               4.0       18.0            4568             28573
#
#    against_society  not_a_crime  against_person_rate  against_property_rate  \
# 0             2134            0          1816.501729           10591.391439
# 1               39            0          1408.057995            3680.468423
# 2             4414            0          2025.505046           12669.605009
#
#    against_society_rate
# 0           1272.206987
# 1            543.705563
# 2           1957.219631
# 22 cols x 1397 rows
#    year    county  arson  assault  bribery  burglary  drug  embezzlement  \
# 0  1997     ADAMS     86     2672        2      1931  1845            26
# 1  1997   ALAMOSA      1       92        0        13    35             0
# 2  1997  ARAPAHOE    138     3872        0      3200  3514           191
#
#    extortion  forgery  ...  kidnapping  larceny_theft  porn  property_damage  \
# 0          5      244  ...          50           8023     1             5467
# 1          0        3  ...           0            165     0               73
# 2         12      672  ...         249          14345     0             5856
#
#    prostitution  robbery  sex_offense  stolen_property  vehicle_theft  \
# 0            14      189          316              245           1317
# 1             0        0            9                0              6
# 2           198      238          434              421           2537
#
#    weapon_law
# 0         274
# 1           4
# 2         695
#
# [3 rows x 22 columns]
# 44 cols x 1397 rows
#    year    county  arson  assault_aggravated  assault_simple  bribery  \
# 0  1997     ADAMS     86                 602            1954        2
# 1  1997   ALAMOSA      1                  14              72        0
# 2  1997  ARAPAHOE    138                 671            2956        0
#
#    burglary  credit_card_machine_fraud  drug_equipment  drug_narcotic  ...  \
# 0      1931                         44             725           1120  ...
# 1        13                          0               8             27  ...
# 2      3200                        194             916           2598  ...
#
#    shoplifting  sodomy  stolen_property  theft_from_building  \
# 0         1323       3              245                 1232
# 1            0       0                0                   14
# 2         4134       0              421                 2283
#
#    theft_from_vehicle  theft_from_vending_machine  vehicle_part_theft  \
# 0                1733                          53                1293
# 1                   7                          10                   1
# 2                3867                          72                 677
#
#    vehicle_theft  weapon_law  wire_fraud
# 0           1317         274           0
# 1              6           4           1
# 2           2537         695           2
#
# [3 rows x 44 columns]

# %% [markdown]
# ### Calculate rates and separate them

# %%
def add_rates(df):
    result = df.copy()[INDEX]
    for c in [c for c in df.columns if c not in df_base.columns]:
        result[f'{c}_rate'] = df[c] / df_base['pop'] * 100_000
    return result

df_cat_rate = add_rates(df_cat)
df_name_rate = add_rates(df_name)
df_base = df_base.drop_cols('pop')

# %%
df_base_rate = df_base[INDEX + ['cr_rate', 'age_avg', 'quarter_mode', 'month_mode', 'day_of_week_mode', 'hour_mode', 'against_person_rate', 'against_property_rate', 'against_society_rate']]
df_base_count = df_base[INDEX + ['cr_count', 'against_person', 'against_property', 'against_society', 'not_a_crime']]

# %%
head(df_base_rate)
# Out:
# 11 cols x 1397 rows
#    year    county       cr_rate    age_avg  quarter_mode  month_mode  \
# 0  1997     ADAMS  13680.100155  24.582071           1.0         3.0
# 1  1997   ALAMOSA   5632.231981  27.098901           3.0         8.0
# 2  1997  ARAPAHOE  16652.329686  25.209156           3.0         8.0
#
#    day_of_week_mode  hour_mode  against_person_rate  against_property_rate  \
# 0               0.0       17.0          1816.501729           10591.391439
# 1               5.0       18.0          1408.057995            3680.468423
# 2               4.0       18.0          2025.505046           12669.605009
#
#    against_society_rate
# 0           1272.206987
# 1            543.705563
# 2           1957.219631

# %%
head(df_base_count)
# Out:
# 7 cols x 1397 rows
#    year    county  cr_count  against_person  against_property  \
# 0  1997     ADAMS     22947            3047             17766
# 1  1997   ALAMOSA       404             101               264
# 2  1997  ARAPAHOE     37555            4568             28573
#
#    against_society  not_a_crime
# 0             2134            0
# 1               39            0
# 2             4414            0

# %%
head(df_cat)
# Out:
# 22 cols x 1397 rows
#    year    county  arson  assault  bribery  burglary  drug  embezzlement  \
# 0  1997     ADAMS     86     2672        2      1931  1845            26
# 1  1997   ALAMOSA      1       92        0        13    35             0
# 2  1997  ARAPAHOE    138     3872        0      3200  3514           191
#
#    extortion  forgery  ...  kidnapping  larceny_theft  porn  property_damage  \
# 0          5      244  ...          50           8023     1             5467
# 1          0        3  ...           0            165     0               73
# 2         12      672  ...         249          14345     0             5856
#
#    prostitution  robbery  sex_offense  stolen_property  vehicle_theft  \
# 0            14      189          316              245           1317
# 1             0        0            9                0              6
# 2           198      238          434              421           2537
#
#    weapon_law
# 0         274
# 1           4
# 2         695
#
# [3 rows x 22 columns]

# %%
head(df_cat_rate)
# Out:
# 22 cols x 1397 rows
#    year    county  arson_rate  assault_rate  bribery_rate  burglary_rate  \
# 0  1997     ADAMS   51.269822   1592.941457      1.192321    1151.186360
# 1  1997   ALAMOSA   13.941168   1282.587481      0.000000     181.235188
# 2  1997  ARAPAHOE   61.190827   1716.890442      0.000000    1418.917721
#
#      drug_rate  embezzlement_rate  extortion_rate  forgery_rate  ...  \
# 0  1099.916537          15.500179        2.980804    145.463217  ...
# 1   487.940889           0.000000        0.000000     41.823505  ...
# 2  1558.149022          84.691651        5.320941    297.972721  ...
#
#    kidnapping_rate  larceny_theft_rate  porn_rate  property_damage_rate  \
# 0        29.808036         4782.997496   0.596161           3259.210683
# 1         0.000000         2300.292765   0.000000           1017.705284
# 2       110.409535         6360.742094   0.000000           2596.619429
#
#    prostitution_rate  robbery_rate  sex_offense_rate  stolen_property_rate  \
# 0           8.346250    112.674377        188.386789            146.059378
# 1           0.000000      0.000000        125.470514              0.000000
# 2          87.795534    105.532005        192.440716            186.676363
#
#    vehicle_theft_rate  weapon_law_rate
# 0          785.143675       163.348039
# 1           83.647010        55.764673
# 2         1124.935705       308.171192
#
# [3 rows x 22 columns]

# %%
head(df_name)
# Out:
# 44 cols x 1397 rows
#    year    county  arson  assault_aggravated  assault_simple  bribery  \
# 0  1997     ADAMS     86                 602            1954        2
# 1  1997   ALAMOSA      1                  14              72        0
# 2  1997  ARAPAHOE    138                 671            2956        0
#
#    burglary  credit_card_machine_fraud  drug_equipment  drug_narcotic  ...  \
# 0      1931                         44             725           1120  ...
# 1        13                          0               8             27  ...
# 2      3200                        194             916           2598  ...
#
#    shoplifting  sodomy  stolen_property  theft_from_building  \
# 0         1323       3              245                 1232
# 1            0       0                0                   14
# 2         4134       0              421                 2283
#
#    theft_from_vehicle  theft_from_vending_machine  vehicle_part_theft  \
# 0                1733                          53                1293
# 1                   7                          10                   1
# 2                3867                          72                 677
#
#    vehicle_theft  weapon_law  wire_fraud
# 0           1317         274           0
# 1              6           4           1
# 2           2537         695           2
#
# [3 rows x 44 columns]

# %%
head(df_name_rate)
# Out:
# 44 cols x 1397 rows
#    year    county  arson_rate  assault_aggravated_rate  assault_simple_rate  \
# 0  1997     ADAMS   51.269822               358.888756          1164.898057
# 1  1997   ALAMOSA   13.941168               195.176356          1003.764115
# 2  1997  ARAPAHOE   61.190827               297.529310          1310.725244
#
#    bribery_rate  burglary_rate  credit_card_machine_fraud_rate  \
# 0      1.192321    1151.186360                       26.231072
# 1      0.000000     181.235188                        0.000000
# 2      0.000000    1418.917721                       86.021887
#
#    drug_equipment_rate  drug_narcotic_rate  ...  shoplifting_rate  \
# 0           432.216526          667.700012  ...        788.720639
# 1           111.529346          376.411543  ...          0.000000
# 2           406.165197         1151.983824  ...       1833.064330
#
#    sodomy_rate  stolen_property_rate  theft_from_building_rate  \
# 0     1.788482            146.059378                734.470013
# 1     0.000000              0.000000                195.176356
# 2     0.000000            186.676363               1012.309111
#
#    theft_from_vehicle_rate  theft_from_vending_machine_rate  \
# 0              1033.146536                        31.596518
# 1                97.588178                       139.411683
# 2              1714.673383                        31.925649
#
#    vehicle_part_theft_rate  vehicle_theft_rate  weapon_law_rate  \
# 0               770.835817          785.143675       163.348039
# 1                13.941168           83.647010        55.764673
# 2               300.189780         1124.935705       308.171192
#
#    wire_fraud_rate
# 0         0.000000
# 1        13.941168
# 2         0.886824
#
# [3 rows x 44 columns]

# %% [markdown]
# ### Output

# %%
write_main(df_base_count, 'crime_agg_base_count')
write_main(df_base_rate, 'crime_agg_base_rate')
write_main(df_cat, 'crime_agg_category')
write_main(df_name, 'crime_agg_name')
write_main(df_cat_rate, 'crime_agg_category_rate')
write_main(df_name_rate, 'crime_agg_name_rate')
# Out:
# 1397

# %% [markdown]
# ---
# ---
# # `7-prepare_for_dashboard`
#
# [BACK TO TOP ^](#top-of-page)
#
# ---
# ---

# %%
dem_norm = read_main('county_stats_normalized')
dem_cnt = read_main('county_stats_counts')

edu_norm = read_main('education_county_rates')
edu_cnt = read_main('education_county_counts')

cr_base_rate = read_main('crime_agg_base_rate')
cr_base_count = read_main('crime_agg_base_count')
cr_cat = read_main('crime_agg_category')
cr_name = read_main('crime_agg_name')
cr_cat_rate = read_main('crime_agg_category_rate')
cr_name_rate = read_main('crime_agg_name_rate')

head(dem_norm, dem_cnt, edu_norm, edu_cnt, cr_base_count, cr_base_rate, cr_cat, cr_name, cr_cat_rate, cr_name_rate)
# Out:
# 58 cols x 512 rows
#    year    county  age_over18_prop  age_undr19_prop  gend_m_prop  gend_f_prop  \
# 0  2012     ADAMS         0.700040         0.299960     2.104797     0.872130
# 1  2012   ALAMOSA         0.718650         0.281350     2.187780     0.803145
# 2  2012  ARAPAHOE         0.725375         0.274625     2.279007     0.797066
#
#    age_undr19_gend_m_prop  age_undr19_gend_f_prop  age_over18_gend_m_prop  \
# 0                2.341611                0.953744                2.003325
# 1                2.611540                0.928669                2.021878
# 2                2.828618                0.951183                2.070926
#
#    age_over18_gend_f_prop  ...  hu_per_cap  age_median  inc_hh_median  \
# 0                0.837159  ...    0.704946        32.4        56633.0
# 1                0.754002  ...    0.840087        32.2        38045.0
# 2                0.738717  ...    0.814089        35.7        60400.0
#
#    hh_size_avg  hu_oo_freq_val_ord  hu_oo_freq_val  hu_blt_freq_yr_ord  \
# 0         2.91                   3      v150k_250k                   7
# 1         2.49                   2       v50k_150k                   1
# 2         2.55                   3      v150k_250k                   4
#
#    hu_blt_freq_yr  med_hm_val  med_yr_blt
# 0      b2000_2009    188100.0      1983.0
# 1         b1949_e    133200.0      1974.0
# 2      b1970_1979    230900.0      1982.0
#
# [3 rows x 58 columns]
# 51 cols x 512 rows
#    year    county       pop    gend_m    gend_f  age_over18  age_undr19  \
# 0  2012     ADAMS  231571.0  487410.0  201960.0    162109.0     69462.0
# 1  2012   ALAMOSA    7823.0   17115.0    6283.0      5622.0      2201.0
# 2  2012  ARAPAHOE  292548.0  666719.0  233180.0    212207.0     80341.0
#
#    gend_m_age_undr19  gend_f_age_undr19  gend_m_age_over18  ...  \
# 0           162653.0            66249.0           324757.0  ...
# 1             5748.0             2044.0            11367.0  ...
# 2           227254.0            76419.0           439465.0  ...
#
#    hu_blt_1990_1999  hu_blt_1980_1989  hu_blt_1970_1979  hu_blt_1960_1969  \
# 0           27598.0           20368.0           30185.0           19615.0
# 1             866.0             862.0            1405.0             654.0
# 2           33989.0           56011.0           62253.0           22258.0
#
#    hu_blt_1950_1959  hu_blt_lt_1950  ps_known  ps_below  ps_undr18_known  \
# 0           20369.0          6158.0  438171.0   62008.0         124375.0
# 1             591.0          1536.0   14622.0    3191.0           3817.0
# 2           16519.0          7165.0  568999.0   66945.0         144576.0
#
#    ps_undr18_below
# 0          25278.0
# 1            758.0
# 2          23054.0
#
# [3 rows x 51 columns]
# 60 cols x 63 rows
#      county  stable_rate  mobile_rate  mobile_instances_rate  \
# 0     ADAMS        68.26        31.68                  34.43
# 1   ALAMOSA        67.82        31.89                  34.23
# 2  ARAPAHOE        75.51        24.18                  25.89
#
#    disabled_stable_rate  disabled_mobile_rate  disabled_mobile_instances_rate  \
# 0                 70.78                 29.25                           32.73
# 1                 71.30                 28.25                           29.60
# 2                 79.89                 19.88                           21.69
#
#    disabled_graduated_rate  disabled_completed_rate  limited_eng_stable_rate  \
# 0                    47.54                    50.10                    69.99
# 1                    86.67                    93.33                    72.01
# 2                    51.26                    52.06                    74.94
#
#    ...  white_mobile_instances_rate  black_stable_rate  black_mobile_rate  \
# 0  ...                        32.45              54.66              45.08
# 1  ...                        35.54              57.14              42.86
# 2  ...                        21.16              67.47              32.03
#
#    black_mobile_instances_rate  hispanic_stable_rate  hispanic_mobile_rate  \
# 0                        47.91                 67.49                 32.71
# 1                        42.86                 70.15                 29.47
# 2                        34.57                 72.76                 26.75
#
#    hispanic_mobile_instances_rate  asian_stable_rate  asian_mobile_rate  \
# 0                           36.40              78.55              21.37
# 1                           32.69              64.00              36.00
# 2                           29.20              78.59              21.30
#
#    asian_mobile_instances_rate
# 0                        23.54
# 1                        36.00
# 2                        22.56
#
# [3 rows x 60 columns]
# 78 cols x 63 rows
#      county  pupil_total  stable  mobile  mobile_instances  \
# 0     ADAMS        98546   67272   31222             33925
# 1   ALAMOSA         2775    1882     885               950
# 2  ARAPAHOE       124639   94109   30134             32269
#
#    disabled_pupil_total  disabled_stable  disabled_mobile  \
# 0                  8848             6263             2588
# 1                   223              159               63
# 2                 11842             9461             2354
#
#    disabled_mobile_instances  limited_eng_pupil_total  ...  migrant_completed  \
# 0                       2896                    20773  ...                 33
# 1                         66                      368  ...                  4
# 2                       2568                    25370  ...                  9
#
#    title_1_grad_base_total  title_1_graduated  title_1_completed  \
# 0                      935                529                559
# 1                       28                 22                 23
# 2                      488                202                213
#
#    homeless_grad_base_total  homeless_graduated  homeless_completed  \
# 0                       360                 190                 204
# 1                         6                   6                   6
# 2                       243                  96                 102
#
#    gifted_grad_base_total  gifted_graduated  gifted_completed
# 0                     402               337               345
# 1                       0                 0                 0
# 2                     909               820               828
#
# [3 rows x 78 columns]
# 7 cols x 1397 rows
#    year    county  cr_count  against_person  against_property  \
# 0  1997     ADAMS     22947            3047             17766
# 1  1997   ALAMOSA       404             101               264
# 2  1997  ARAPAHOE     37555            4568             28573
#
#    against_society  not_a_crime
# 0             2134            0
# 1               39            0
# 2             4414            0
# 11 cols x 1397 rows
#    year    county       cr_rate    age_avg  quarter_mode  month_mode  \
# 0  1997     ADAMS  13680.100155  24.582071           1.0         3.0
# 1  1997   ALAMOSA   5632.231981  27.098901           3.0         8.0
# 2  1997  ARAPAHOE  16652.329686  25.209156           3.0         8.0
#
#    day_of_week_mode  hour_mode  against_person_rate  against_property_rate  \
# 0               0.0       17.0          1816.501729           10591.391439
# 1               5.0       18.0          1408.057995            3680.468423
# 2               4.0       18.0          2025.505046           12669.605009
#
#    against_society_rate
# 0           1272.206987
# 1            543.705563
# 2           1957.219631
# 22 cols x 1397 rows
#    year    county  arson  assault  bribery  burglary  drug  embezzlement  \
# 0  1997     ADAMS     86     2672        2      1931  1845            26
# 1  1997   ALAMOSA      1       92        0        13    35             0
# 2  1997  ARAPAHOE    138     3872        0      3200  3514           191
#
#    extortion  forgery  ...  kidnapping  larceny_theft  porn  property_damage  \
# 0          5      244  ...          50           8023     1             5467
# 1          0        3  ...           0            165     0               73
# 2         12      672  ...         249          14345     0             5856
#
#    prostitution  robbery  sex_offense  stolen_property  vehicle_theft  \
# 0            14      189          316              245           1317
# 1             0        0            9                0              6
# 2           198      238          434              421           2537
#
#    weapon_law
# 0         274
# 1           4
# 2         695
#
# [3 rows x 22 columns]
# 44 cols x 1397 rows
#    year    county  arson  assault_aggravated  assault_simple  bribery  \
# 0  1997     ADAMS     86                 602            1954        2
# 1  1997   ALAMOSA      1                  14              72        0
# 2  1997  ARAPAHOE    138                 671            2956        0
#
#    burglary  credit_card_machine_fraud  drug_equipment  drug_narcotic  ...  \
# 0      1931                         44             725           1120  ...
# 1        13                          0               8             27  ...
# 2      3200                        194             916           2598  ...
#
#    shoplifting  sodomy  stolen_property  theft_from_building  \
# 0         1323       3              245                 1232
# 1            0       0                0                   14
# 2         4134       0              421                 2283
#
#    theft_from_vehicle  theft_from_vending_machine  vehicle_part_theft  \
# 0                1733                          53                1293
# 1                   7                          10                   1
# 2                3867                          72                 677
#
#    vehicle_theft  weapon_law  wire_fraud
# 0           1317         274           0
# 1              6           4           1
# 2           2537         695           2
#
# [3 rows x 44 columns]
# 22 cols x 1397 rows
#    year    county  arson_rate  assault_rate  bribery_rate  burglary_rate  \
# 0  1997     ADAMS   51.269822   1592.941457      1.192321    1151.186360
# 1  1997   ALAMOSA   13.941168   1282.587481      0.000000     181.235188
# 2  1997  ARAPAHOE   61.190827   1716.890442      0.000000    1418.917721
#
#      drug_rate  embezzlement_rate  extortion_rate  forgery_rate  ...  \
# 0  1099.916537          15.500179        2.980804    145.463217  ...
# 1   487.940889           0.000000        0.000000     41.823505  ...
# 2  1558.149022          84.691651        5.320941    297.972721  ...
#
#    kidnapping_rate  larceny_theft_rate  porn_rate  property_damage_rate  \
# 0        29.808036         4782.997496   0.596161           3259.210683
# 1         0.000000         2300.292765   0.000000           1017.705284
# 2       110.409535         6360.742094   0.000000           2596.619429
#
#    prostitution_rate  robbery_rate  sex_offense_rate  stolen_property_rate  \
# 0           8.346250    112.674377        188.386789            146.059378
# 1           0.000000      0.000000        125.470514              0.000000
# 2          87.795534    105.532005        192.440716            186.676363
#
#    vehicle_theft_rate  weapon_law_rate
# 0          785.143675       163.348039
# 1           83.647010        55.764673
# 2         1124.935705       308.171192
#
# [3 rows x 22 columns]
# 44 cols x 1397 rows
#    year    county  arson_rate  assault_aggravated_rate  assault_simple_rate  \
# 0  1997     ADAMS   51.269822               358.888756          1164.898057
# 1  1997   ALAMOSA   13.941168               195.176356          1003.764115
# 2  1997  ARAPAHOE   61.190827               297.529310          1310.725244
#
#    bribery_rate  burglary_rate  credit_card_machine_fraud_rate  \
# 0      1.192321    1151.186360                       26.231072
# 1      0.000000     181.235188                        0.000000
# 2      0.000000    1418.917721                       86.021887
#
#    drug_equipment_rate  drug_narcotic_rate  ...  shoplifting_rate  \
# 0           432.216526          667.700012  ...        788.720639
# 1           111.529346          376.411543  ...          0.000000
# 2           406.165197         1151.983824  ...       1833.064330
#
#    sodomy_rate  stolen_property_rate  theft_from_building_rate  \
# 0     1.788482            146.059378                734.470013
# 1     0.000000              0.000000                195.176356
# 2     0.000000            186.676363               1012.309111
#
#    theft_from_vehicle_rate  theft_from_vending_machine_rate  \
# 0              1033.146536                        31.596518
# 1                97.588178                       139.411683
# 2              1714.673383                        31.925649
#
#    vehicle_part_theft_rate  vehicle_theft_rate  weapon_law_rate  \
# 0               770.835817          785.143675       163.348039
# 1                13.941168           83.647010        55.764673
# 2               300.189780         1124.935705       308.171192
#
#    wire_fraud_rate
# 0         0.000000
# 1        13.941168
# 2         0.886824
#
# [3 rows x 44 columns]

# %%
INDEX = ['year', 'county']

def non_idx_cols(df, index=INDEX):
    return [col for col in df.columns if col not in index]

# %%
cr_name = cr_name.prefix_cols(non_idx_cols(cr_name), 'CRIME_NAME_COUNT__')
cr_cat = cr_cat.prefix_cols(non_idx_cols(cr_cat), 'CRIME_CATEGORY_COUNT__')

cr_name_rate = cr_name_rate.prefix_cols(non_idx_cols(cr_name_rate), 'CRIME_NAME_NORM__')
cr_cat_rate = cr_cat_rate.prefix_cols(non_idx_cols(cr_cat_rate), 'CRIME_CATEGORY_NORM__')

cr_base_count = cr_base_count.prefix_cols(non_idx_cols(cr_base_count), 'CRIME_BASE_COUNT__')
cr_base_rate = cr_base_rate.prefix_cols(non_idx_cols(cr_base_rate), 'CRIME_BASE_NORM__')

dem_cnt = dem_cnt.prefix_cols(non_idx_cols(dem_cnt), 'CENSUS_COUNT__')
dem_norm = dem_norm.prefix_cols(non_idx_cols(dem_norm), 'CENSUS_NORM__')

edu_cnt = edu_cnt.prefix_cols(non_idx_cols(edu_cnt, ['county']), 'EDU_COUNT__')
edu_norm = edu_norm.prefix_cols(non_idx_cols(edu_norm, ['county']), 'EDU_NORM__')

head(cr_name, cr_cat, cr_name_rate, cr_cat_rate, cr_base_count, cr_base_rate, dem_cnt, dem_norm, edu_cnt, edu_norm)
# Out:
# 44 cols x 1397 rows
#    year    county  CRIME_NAME_COUNT__arson  \
# 0  1997     ADAMS                       86
# 1  1997   ALAMOSA                        1
# 2  1997  ARAPAHOE                      138
#
#    CRIME_NAME_COUNT__assault_aggravated  CRIME_NAME_COUNT__assault_simple  \
# 0                                   602                              1954
# 1                                    14                                72
# 2                                   671                              2956
#
#    CRIME_NAME_COUNT__bribery  CRIME_NAME_COUNT__burglary  \
# 0                          2                        1931
# 1                          0                          13
# 2                          0                        3200
#
#    CRIME_NAME_COUNT__credit_card_machine_fraud  \
# 0                                           44
# 1                                            0
# 2                                          194
#
#    CRIME_NAME_COUNT__drug_equipment  CRIME_NAME_COUNT__drug_narcotic  ...  \
# 0                               725                             1120  ...
# 1                                 8                               27  ...
# 2                               916                             2598  ...
#
#    CRIME_NAME_COUNT__shoplifting  CRIME_NAME_COUNT__sodomy  \
# 0                           1323                         3
# 1                              0                         0
# 2                           4134                         0
#
#    CRIME_NAME_COUNT__stolen_property  CRIME_NAME_COUNT__theft_from_building  \
# 0                                245                                   1232
# 1                                  0                                     14
# 2                                421                                   2283
#
#    CRIME_NAME_COUNT__theft_from_vehicle  \
# 0                                  1733
# 1                                     7
# 2                                  3867
#
#    CRIME_NAME_COUNT__theft_from_vending_machine  \
# 0                                            53
# 1                                            10
# 2                                            72
#
#    CRIME_NAME_COUNT__vehicle_part_theft  CRIME_NAME_COUNT__vehicle_theft  \
# 0                                  1293                             1317
# 1                                     1                                6
# 2                                   677                             2537
#
#    CRIME_NAME_COUNT__weapon_law  CRIME_NAME_COUNT__wire_fraud
# 0                           274                             0
# 1                             4                             1
# 2                           695                             2
#
# [3 rows x 44 columns]
# 22 cols x 1397 rows
#    year    county  CRIME_CATEGORY_COUNT__arson  CRIME_CATEGORY_COUNT__assault  \
# 0  1997     ADAMS                           86                           2672
# 1  1997   ALAMOSA                            1                             92
# 2  1997  ARAPAHOE                          138                           3872
#
#    CRIME_CATEGORY_COUNT__bribery  CRIME_CATEGORY_COUNT__burglary  \
# 0                              2                            1931
# 1                              0                              13
# 2                              0                            3200
#
#    CRIME_CATEGORY_COUNT__drug  CRIME_CATEGORY_COUNT__embezzlement  \
# 0                        1845                                  26
# 1                          35                                   0
# 2                        3514                                 191
#
#    CRIME_CATEGORY_COUNT__extortion  CRIME_CATEGORY_COUNT__forgery  ...  \
# 0                                5                            244  ...
# 1                                0                              3  ...
# 2                               12                            672  ...
#
#    CRIME_CATEGORY_COUNT__kidnapping  CRIME_CATEGORY_COUNT__larceny_theft  \
# 0                                50                                 8023
# 1                                 0                                  165
# 2                               249                                14345
#
#    CRIME_CATEGORY_COUNT__porn  CRIME_CATEGORY_COUNT__property_damage  \
# 0                           1                                   5467
# 1                           0                                     73
# 2                           0                                   5856
#
#    CRIME_CATEGORY_COUNT__prostitution  CRIME_CATEGORY_COUNT__robbery  \
# 0                                  14                            189
# 1                                   0                              0
# 2                                 198                            238
#
#    CRIME_CATEGORY_COUNT__sex_offense  CRIME_CATEGORY_COUNT__stolen_property  \
# 0                                316                                    245
# 1                                  9                                      0
# 2                                434                                    421
#
#    CRIME_CATEGORY_COUNT__vehicle_theft  CRIME_CATEGORY_COUNT__weapon_law
# 0                                 1317                               274
# 1                                    6                                 4
# 2                                 2537                               695
#
# [3 rows x 22 columns]
# 44 cols x 1397 rows
#    year    county  CRIME_NAME_NORM__arson_rate  \
# 0  1997     ADAMS                    51.269822
# 1  1997   ALAMOSA                    13.941168
# 2  1997  ARAPAHOE                    61.190827
#
#    CRIME_NAME_NORM__assault_aggravated_rate  \
# 0                                358.888756
# 1                                195.176356
# 2                                297.529310
#
#    CRIME_NAME_NORM__assault_simple_rate  CRIME_NAME_NORM__bribery_rate  \
# 0                           1164.898057                       1.192321
# 1                           1003.764115                       0.000000
# 2                           1310.725244                       0.000000
#
#    CRIME_NAME_NORM__burglary_rate  \
# 0                     1151.186360
# 1                      181.235188
# 2                     1418.917721
#
#    CRIME_NAME_NORM__credit_card_machine_fraud_rate  \
# 0                                        26.231072
# 1                                         0.000000
# 2                                        86.021887
#
#    CRIME_NAME_NORM__drug_equipment_rate  CRIME_NAME_NORM__drug_narcotic_rate  \
# 0                            432.216526                           667.700012
# 1                            111.529346                           376.411543
# 2                            406.165197                          1151.983824
#
#    ...  CRIME_NAME_NORM__shoplifting_rate  CRIME_NAME_NORM__sodomy_rate  \
# 0  ...                         788.720639                      1.788482
# 1  ...                           0.000000                      0.000000
# 2  ...                        1833.064330                      0.000000
#
#    CRIME_NAME_NORM__stolen_property_rate  \
# 0                             146.059378
# 1                               0.000000
# 2                             186.676363
#
#    CRIME_NAME_NORM__theft_from_building_rate  \
# 0                                 734.470013
# 1                                 195.176356
# 2                                1012.309111
#
#    CRIME_NAME_NORM__theft_from_vehicle_rate  \
# 0                               1033.146536
# 1                                 97.588178
# 2                               1714.673383
#
#    CRIME_NAME_NORM__theft_from_vending_machine_rate  \
# 0                                         31.596518
# 1                                        139.411683
# 2                                         31.925649
#
#    CRIME_NAME_NORM__vehicle_part_theft_rate  \
# 0                                770.835817
# 1                                 13.941168
# 2                                300.189780
#
#    CRIME_NAME_NORM__vehicle_theft_rate  CRIME_NAME_NORM__weapon_law_rate  \
# 0                           785.143675                        163.348039
# 1                            83.647010                         55.764673
# 2                          1124.935705                        308.171192
#
#    CRIME_NAME_NORM__wire_fraud_rate
# 0                          0.000000
# 1                         13.941168
# 2                          0.886824
#
# [3 rows x 44 columns]
# 22 cols x 1397 rows
#    year    county  CRIME_CATEGORY_NORM__arson_rate  \
# 0  1997     ADAMS                        51.269822
# 1  1997   ALAMOSA                        13.941168
# 2  1997  ARAPAHOE                        61.190827
#
#    CRIME_CATEGORY_NORM__assault_rate  CRIME_CATEGORY_NORM__bribery_rate  \
# 0                        1592.941457                           1.192321
# 1                        1282.587481                           0.000000
# 2                        1716.890442                           0.000000
#
#    CRIME_CATEGORY_NORM__burglary_rate  CRIME_CATEGORY_NORM__drug_rate  \
# 0                         1151.186360                     1099.916537
# 1                          181.235188                      487.940889
# 2                         1418.917721                     1558.149022
#
#    CRIME_CATEGORY_NORM__embezzlement_rate  \
# 0                               15.500179
# 1                                0.000000
# 2                               84.691651
#
#    CRIME_CATEGORY_NORM__extortion_rate  CRIME_CATEGORY_NORM__forgery_rate  \
# 0                             2.980804                         145.463217
# 1                             0.000000                          41.823505
# 2                             5.320941                         297.972721
#
#    ...  CRIME_CATEGORY_NORM__kidnapping_rate  \
# 0  ...                             29.808036
# 1  ...                              0.000000
# 2  ...                            110.409535
#
#    CRIME_CATEGORY_NORM__larceny_theft_rate  CRIME_CATEGORY_NORM__porn_rate  \
# 0                              4782.997496                        0.596161
# 1                              2300.292765                        0.000000
# 2                              6360.742094                        0.000000
#
#    CRIME_CATEGORY_NORM__property_damage_rate  \
# 0                                3259.210683
# 1                                1017.705284
# 2                                2596.619429
#
#    CRIME_CATEGORY_NORM__prostitution_rate  CRIME_CATEGORY_NORM__robbery_rate  \
# 0                                8.346250                         112.674377
# 1                                0.000000                           0.000000
# 2                               87.795534                         105.532005
#
#    CRIME_CATEGORY_NORM__sex_offense_rate  \
# 0                             188.386789
# 1                             125.470514
# 2                             192.440716
#
#    CRIME_CATEGORY_NORM__stolen_property_rate  \
# 0                                 146.059378
# 1                                   0.000000
# 2                                 186.676363
#
#    CRIME_CATEGORY_NORM__vehicle_theft_rate  \
# 0                               785.143675
# 1                                83.647010
# 2                              1124.935705
#
#    CRIME_CATEGORY_NORM__weapon_law_rate
# 0                            163.348039
# 1                             55.764673
# 2                            308.171192
#
# [3 rows x 22 columns]
# 7 cols x 1397 rows
#    year    county  CRIME_BASE_COUNT__cr_count  \
# 0  1997     ADAMS                       22947
# 1  1997   ALAMOSA                         404
# 2  1997  ARAPAHOE                       37555
#
#    CRIME_BASE_COUNT__against_person  CRIME_BASE_COUNT__against_property  \
# 0                              3047                               17766
# 1                               101                                 264
# 2                              4568                               28573
#
#    CRIME_BASE_COUNT__against_society  CRIME_BASE_COUNT__not_a_crime
# 0                               2134                              0
# 1                                 39                              0
# 2                               4414                              0
# 11 cols x 1397 rows
#    year    county  CRIME_BASE_NORM__cr_rate  CRIME_BASE_NORM__age_avg  \
# 0  1997     ADAMS              13680.100155                 24.582071
# 1  1997   ALAMOSA               5632.231981                 27.098901
# 2  1997  ARAPAHOE              16652.329686                 25.209156
#
#    CRIME_BASE_NORM__quarter_mode  CRIME_BASE_NORM__month_mode  \
# 0                            1.0                          3.0
# 1                            3.0                          8.0
# 2                            3.0                          8.0
#
#    CRIME_BASE_NORM__day_of_week_mode  CRIME_BASE_NORM__hour_mode  \
# 0                                0.0                        17.0
# 1                                5.0                        18.0
# 2                                4.0                        18.0
#
#    CRIME_BASE_NORM__against_person_rate  \
# 0                           1816.501729
# 1                           1408.057995
# 2                           2025.505046
#
#    CRIME_BASE_NORM__against_property_rate  \
# 0                            10591.391439
# 1                             3680.468423
# 2                            12669.605009
#
#    CRIME_BASE_NORM__against_society_rate
# 0                            1272.206987
# 1                             543.705563
# 2                            1957.219631
# 51 cols x 512 rows
#    year    county  CENSUS_COUNT__pop  CENSUS_COUNT__gend_m  \
# 0  2012     ADAMS           231571.0              487410.0
# 1  2012   ALAMOSA             7823.0               17115.0
# 2  2012  ARAPAHOE           292548.0              666719.0
#
#    CENSUS_COUNT__gend_f  CENSUS_COUNT__age_over18  CENSUS_COUNT__age_undr19  \
# 0              201960.0                  162109.0                   69462.0
# 1                6283.0                    5622.0                    2201.0
# 2              233180.0                  212207.0                   80341.0
#
#    CENSUS_COUNT__gend_m_age_undr19  CENSUS_COUNT__gend_f_age_undr19  \
# 0                         162653.0                          66249.0
# 1                           5748.0                           2044.0
# 2                         227254.0                          76419.0
#
#    CENSUS_COUNT__gend_m_age_over18  ...  CENSUS_COUNT__hu_blt_1990_1999  \
# 0                         324757.0  ...                         27598.0
# 1                          11367.0  ...                           866.0
# 2                         439465.0  ...                         33989.0
#
#    CENSUS_COUNT__hu_blt_1980_1989  CENSUS_COUNT__hu_blt_1970_1979  \
# 0                         20368.0                         30185.0
# 1                           862.0                          1405.0
# 2                         56011.0                         62253.0
#
#    CENSUS_COUNT__hu_blt_1960_1969  CENSUS_COUNT__hu_blt_1950_1959  \
# 0                         19615.0                         20369.0
# 1                           654.0                           591.0
# 2                         22258.0                         16519.0
#
#    CENSUS_COUNT__hu_blt_lt_1950  CENSUS_COUNT__ps_known  \
# 0                        6158.0                438171.0
# 1                        1536.0                 14622.0
# 2                        7165.0                568999.0
#
#    CENSUS_COUNT__ps_below  CENSUS_COUNT__ps_undr18_known  \
# 0                 62008.0                       124375.0
# 1                  3191.0                         3817.0
# 2                 66945.0                       144576.0
#
#    CENSUS_COUNT__ps_undr18_below
# 0                        25278.0
# 1                          758.0
# 2                        23054.0
#
# [3 rows x 51 columns]
# 58 cols x 512 rows
#    year    county  CENSUS_NORM__age_over18_prop  CENSUS_NORM__age_undr19_prop  \
# 0  2012     ADAMS                      0.700040                      0.299960
# 1  2012   ALAMOSA                      0.718650                      0.281350
# 2  2012  ARAPAHOE                      0.725375                      0.274625
#
#    CENSUS_NORM__gend_m_prop  CENSUS_NORM__gend_f_prop  \
# 0                  2.104797                  0.872130
# 1                  2.187780                  0.803145
# 2                  2.279007                  0.797066
#
#    CENSUS_NORM__age_undr19_gend_m_prop  CENSUS_NORM__age_undr19_gend_f_prop  \
# 0                             2.341611                             0.953744
# 1                             2.611540                             0.928669
# 2                             2.828618                             0.951183
#
#    CENSUS_NORM__age_over18_gend_m_prop  CENSUS_NORM__age_over18_gend_f_prop  \
# 0                             2.003325                             0.837159
# 1                             2.021878                             0.754002
# 2                             2.070926                             0.738717
#
#    ...  CENSUS_NORM__hu_per_cap  CENSUS_NORM__age_median  \
# 0  ...                 0.704946                     32.4
# 1  ...                 0.840087                     32.2
# 2  ...                 0.814089                     35.7
#
#    CENSUS_NORM__inc_hh_median  CENSUS_NORM__hh_size_avg  \
# 0                     56633.0                      2.91
# 1                     38045.0                      2.49
# 2                     60400.0                      2.55
#
#    CENSUS_NORM__hu_oo_freq_val_ord  CENSUS_NORM__hu_oo_freq_val  \
# 0                                3                   v150k_250k
# 1                                2                    v50k_150k
# 2                                3                   v150k_250k
#
#    CENSUS_NORM__hu_blt_freq_yr_ord  CENSUS_NORM__hu_blt_freq_yr  \
# 0                                7                   b2000_2009
# 1                                1                      b1949_e
# 2                                4                   b1970_1979
#
#    CENSUS_NORM__med_hm_val  CENSUS_NORM__med_yr_blt
# 0                 188100.0                   1983.0
# 1                 133200.0                   1974.0
# 2                 230900.0                   1982.0
#
# [3 rows x 58 columns]
# 78 cols x 63 rows
#      county  EDU_COUNT__pupil_total  EDU_COUNT__stable  EDU_COUNT__mobile  \
# 0     ADAMS                   98546              67272              31222
# 1   ALAMOSA                    2775               1882                885
# 2  ARAPAHOE                  124639              94109              30134
#
#    EDU_COUNT__mobile_instances  EDU_COUNT__disabled_pupil_total  \
# 0                        33925                             8848
# 1                          950                              223
# 2                        32269                            11842
#
#    EDU_COUNT__disabled_stable  EDU_COUNT__disabled_mobile  \
# 0                        6263                        2588
# 1                         159                          63
# 2                        9461                        2354
#
#    EDU_COUNT__disabled_mobile_instances  EDU_COUNT__limited_eng_pupil_total  \
# 0                                  2896                               20773
# 1                                    66                                 368
# 2                                  2568                               25370
#
#    ...  EDU_COUNT__migrant_completed  EDU_COUNT__title_1_grad_base_total  \
# 0  ...                            33                                 935
# 1  ...                             4                                  28
# 2  ...                             9                                 488
#
#    EDU_COUNT__title_1_graduated  EDU_COUNT__title_1_completed  \
# 0                           529                           559
# 1                            22                            23
# 2                           202                           213
#
#    EDU_COUNT__homeless_grad_base_total  EDU_COUNT__homeless_graduated  \
# 0                                  360                            190
# 1                                    6                              6
# 2                                  243                             96
#
#    EDU_COUNT__homeless_completed  EDU_COUNT__gifted_grad_base_total  \
# 0                            204                                402
# 1                              6                                  0
# 2                            102                                909
#
#    EDU_COUNT__gifted_graduated  EDU_COUNT__gifted_completed
# 0                          337                          345
# 1                            0                            0
# 2                          820                          828
#
# [3 rows x 78 columns]
# 60 cols x 63 rows
#      county  EDU_NORM__stable_rate  EDU_NORM__mobile_rate  \
# 0     ADAMS                  68.26                  31.68
# 1   ALAMOSA                  67.82                  31.89
# 2  ARAPAHOE                  75.51                  24.18
#
#    EDU_NORM__mobile_instances_rate  EDU_NORM__disabled_stable_rate  \
# 0                            34.43                           70.78
# 1                            34.23                           71.30
# 2                            25.89                           79.89
#
#    EDU_NORM__disabled_mobile_rate  EDU_NORM__disabled_mobile_instances_rate  \
# 0                           29.25                                     32.73
# 1                           28.25                                     29.60
# 2                           19.88                                     21.69
#
#    EDU_NORM__disabled_graduated_rate  EDU_NORM__disabled_completed_rate  \
# 0                              47.54                              50.10
# 1                              86.67                              93.33
# 2                              51.26                              52.06
#
#    EDU_NORM__limited_eng_stable_rate  ...  \
# 0                              69.99  ...
# 1                              72.01  ...
# 2                              74.94  ...
#
#    EDU_NORM__white_mobile_instances_rate  EDU_NORM__black_stable_rate  \
# 0                                  32.45                        54.66
# 1                                  35.54                        57.14
# 2                                  21.16                        67.47
#
#    EDU_NORM__black_mobile_rate  EDU_NORM__black_mobile_instances_rate  \
# 0                        45.08                                  47.91
# 1                        42.86                                  42.86
# 2                        32.03                                  34.57
#
#    EDU_NORM__hispanic_stable_rate  EDU_NORM__hispanic_mobile_rate  \
# 0                           67.49                           32.71
# 1                           70.15                           29.47
# 2                           72.76                           26.75
#
#    EDU_NORM__hispanic_mobile_instances_rate  EDU_NORM__asian_stable_rate  \
# 0                                     36.40                        78.55
# 1                                     32.69                        64.00
# 2                                     29.20                        78.59
#
#    EDU_NORM__asian_mobile_rate  EDU_NORM__asian_mobile_instances_rate
# 0                        21.37                                  23.54
# 1                        36.00                                  36.00
# 2                        21.30                                  22.56
#
# [3 rows x 60 columns]

# %%
df = (
    # CRIME
    cr_name
    .merge(cr_cat, on=INDEX)
    .merge(
        (
            cr_name_rate
            .merge(cr_cat_rate, on=INDEX)
        ),
        on=INDEX
    )
    .merge(
        (
            cr_base_count
            .merge(cr_base_rate, on=INDEX)
        ),
        on=INDEX
    )
    # DEMOGRAPHICS
    .merge(
        (
            dem_cnt
            .merge(dem_norm, on=INDEX)
        ),
        on=INDEX
    )
    # EDUCATION
    .merge(
        (
            edu_cnt
            .merge(edu_norm, on=['county'])
        ),
        on=['county']
    )
)

# %%
# Change all numbers to floats, and round
numeric_cols = df.select_dtypes(include=[np.number])
df[numeric_cols.columns] = numeric_cols.astype(float).round(2)
df.year = df.year.astype(int)
head(df)
# Out:
# 381 cols x 490 rows
#    year county  CRIME_NAME_COUNT__arson  CRIME_NAME_COUNT__assault_aggravated  \
# 0  2012  ADAMS                    105.0                                1029.0
# 1  2013  ADAMS                     73.0                                 899.0
# 2  2014  ADAMS                    123.0                                1033.0
#
#    CRIME_NAME_COUNT__assault_simple  CRIME_NAME_COUNT__bribery  \
# 0                            2835.0                        2.0
# 1                            2649.0                        7.0
# 2                            2863.0                        8.0
#
#    CRIME_NAME_COUNT__burglary  CRIME_NAME_COUNT__credit_card_machine_fraud  \
# 0                      2311.0                                        535.0
# 1                      2144.0                                        437.0
# 2                      2073.0                                        526.0
#
#    CRIME_NAME_COUNT__drug_equipment  CRIME_NAME_COUNT__drug_narcotic  ...  \
# 0                            3211.0                           3522.0  ...
# 1                            1965.0                           2204.0  ...
# 2                            1945.0                           2145.0  ...
#
#    EDU_NORM__white_mobile_instances_rate  EDU_NORM__black_stable_rate  \
# 0                                  32.45                        54.66
# 1                                  32.45                        54.66
# 2                                  32.45                        54.66
#
#    EDU_NORM__black_mobile_rate  EDU_NORM__black_mobile_instances_rate  \
# 0                        45.08                                  47.91
# 1                        45.08                                  47.91
# 2                        45.08                                  47.91
#
#    EDU_NORM__hispanic_stable_rate  EDU_NORM__hispanic_mobile_rate  \
# 0                           67.49                           32.71
# 1                           67.49                           32.71
# 2                           67.49                           32.71
#
#    EDU_NORM__hispanic_mobile_instances_rate  EDU_NORM__asian_stable_rate  \
# 0                                      36.4                        78.55
# 1                                      36.4                        78.55
# 2                                      36.4                        78.55
#
#    EDU_NORM__asian_mobile_rate  EDU_NORM__asian_mobile_instances_rate
# 0                        21.37                                  23.54
# 1                        21.37                                  23.54
# 2                        21.37                                  23.54
#
# [3 rows x 381 columns]

# %%
## TEMPORARY - REVERSE OUR WORK
df.columns = [c if '__' not in c else c.split('__')[1] for c in df.columns]
df = df.loc[:, ~ df.columns.duplicated()]
head(df)
# Out:
# 353 cols x 490 rows
#    year county  arson  assault_aggravated  assault_simple  bribery  burglary  \
# 0  2012  ADAMS  105.0              1029.0          2835.0      2.0    2311.0
# 1  2013  ADAMS   73.0               899.0          2649.0      7.0    2144.0
# 2  2014  ADAMS  123.0              1033.0          2863.0      8.0    2073.0
#
#    credit_card_machine_fraud  drug_equipment  drug_narcotic  ...  \
# 0                      535.0          3211.0         3522.0  ...
# 1                      437.0          1965.0         2204.0  ...
# 2                      526.0          1945.0         2145.0  ...
#
#    white_mobile_instances_rate  black_stable_rate  black_mobile_rate  \
# 0                        32.45              54.66              45.08
# 1                        32.45              54.66              45.08
# 2                        32.45              54.66              45.08
#
#    black_mobile_instances_rate  hispanic_stable_rate  hispanic_mobile_rate  \
# 0                        47.91                 67.49                 32.71
# 1                        47.91                 67.49                 32.71
# 2                        47.91                 67.49                 32.71
#
#    hispanic_mobile_instances_rate  asian_stable_rate  asian_mobile_rate  \
# 0                            36.4              78.55              21.37
# 1                            36.4              78.55              21.37
# 2                            36.4              78.55              21.37
#
#    asian_mobile_instances_rate
# 0                        23.54
# 1                        23.54
# 2                        23.54
#
# [3 rows x 353 columns]

# %%
write_main(df, 'county_EVERYTHING')
# Out:
# 490

# %% [markdown]
# ## District

# %%
df_dist = read_main('education_dist')
df_geo_dist = read_main('''
    d.district,
    c.county,
    d.geo_border AS geo_district_border,
    c.geo_border AS geo_county_border,
    d.geo_point AS geo_district_point,
    c.geo_point AS geo_county_point
FROM district AS d
INNER JOIN county AS c
    ON c.county = d.in_county
''')

# %%
df_dist = (df_geo_dist
    .merge(df_dist, on=['district'])
    [ ~ df_geo_dist.geo_district_border.isna()]
)

head(df_dist)
# Out:
# 142 cols x 178 rows
#            district county                                geo_district_border  \
# 0        MAPLETON 1  ADAMS  MULTIPOLYGON (((-105.01581612299998 39.8144774...
# 1  ADAMSFIVESTAR 12  ADAMS  MULTIPOLYGON (((-105.05310614499996 39.9302934...
# 2    ADAMSCOUNTY 14  ADAMS  MULTIPOLYGON (((-104.96883410999999 39.7910064...
#
#                                    geo_county_border  \
# 0  MULTIPOLYGON (((-103.70574149517748 39.9999110...
# 1  MULTIPOLYGON (((-103.70574149517748 39.9999110...
# 2  MULTIPOLYGON (((-103.70574149517748 39.9999110...
#
#          geo_district_point          geo_county_point  pupil_total  stable  \
# 0  GEOMETRYCOLLECTION EMPTY  GEOMETRYCOLLECTION EMPTY         9037    5077
# 1  GEOMETRYCOLLECTION EMPTY  GEOMETRYCOLLECTION EMPTY        49889   34283
# 2  GEOMETRYCOLLECTION EMPTY  GEOMETRYCOLLECTION EMPTY         8265    5510
#
#    mobile  mobile_instances  ...  white_mobile_instances_rate  \
# 0    3919              4133  ...                        52.08
# 1   15424             16854  ...                        32.27
# 2    3038              3397  ...                        47.45
#
#    black_stable_rate  black_mobile_rate  black_mobile_instances_rate  \
# 0              48.04              51.40                        53.63
# 1              55.98              43.94                        47.41
# 2              48.20              51.80                        53.60
#
#    hispanic_stable_rate  hispanic_mobile_rate  hispanic_mobile_instances_rate  \
# 0                 60.31                 39.19                           42.19
# 1                 67.30                 32.23                           36.81
# 2                 68.67                 35.20                           39.57
#
#    asian_stable_rate  asian_mobile_rate  asian_mobile_instances_rate
# 0              47.22              52.78                        53.70
# 1              81.07              18.84                        21.15
# 2              80.00              20.00                        20.00
#
# [3 rows x 142 columns]

# %%
write_main(df_dist, 'district_EVERYTHING')
# Out:
# 178

# %% [markdown]
# ## Generate combined notebook output

# %%
from combine_notebooks import combine

combine(
    filename="8-combined (AUTO GENERATED FILE)",
)
