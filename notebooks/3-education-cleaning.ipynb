# %% [markdown]
# # Education data prep
#
# ### Standardizing county names, and general cleaning/refactoring
#
# - We have 3 education datasets:
#   - graduation rates
#   - student mobility
#   - student mobility by demographics
#
# Fortunately, just ONE of them (grad rate) has a county column. Using the district column present in all 3 datasets, we will merge the county column with the other two datasets

# %%
import pandas as pd
df_grad_rate = pd.read_csv('../input-data/dist_grad_rate__cfyh-6xxg.csv')
df_mobility = pd.read_csv('../input-data/dist_student_mobility__6wcd-ysh5.csv')
df_mobility_demo = pd.read_csv('../input-data/dist_mobility_demographics__rg84-k4d3.csv')

# %% [markdown]
# ## Manual edits of county name

# %%
df = df_grad_rate.copy()[['organization_name', 'county_name']]

org_name_to_county_name_map = {
    'STATE TOTAL': 'STATE TOTAL',
    'CHARTER SCHOOL INSTITUTE': 'DENVER',
    'MOUNTAIN BOCES': 'CHAFFEE',
    'CENTENNIAL BOCES': 'WELD',
    'SAN JUAN BOCES': 'LA PLATA',
    'EXPEDITIONARY BOCES': 'DENVER',
}
for org_name, new_county_name in org_name_to_county_name_map.items():
    df.loc[df.organization_name == org_name, 'county_name'] = new_county_name

county = df
county
# Out:
#               organization_name  county_name
# 0                   STATE TOTAL  STATE TOTAL
# 1                    MAPLETON 1        ADAMS
# 2    ADAMS 12 FIVE STAR SCHOOLS        ADAMS
# 3               ADAMS COUNTY 14        ADAMS
# 4                  BRIGHTON 27J        ADAMS
# ..                          ...          ...
# 180              MOUNTAIN BOCES      CHAFFEE
# 181            CENTENNIAL BOCES         WELD
# 182              SAN JUAN BOCES     LA PLATA
# 183         EXPEDITIONARY BOCES       DENVER
# 184                 STATE TOTAL  STATE TOTAL
#
# [185 rows x 2 columns]

# %% [markdown]
# ### Do the stuff
# 1. Merge county column
# 2. Refactor county and bring to front.
# 3. Drop unneeded columns
# 4. Drop duplicates (for some reason the 'STATE TOTAL' row is duplicated 2-4 times on some of the datasets. Weird.)
# 5. Repeat for the other two datasets

# %%
df = df_mobility.copy()
df = (county
    .merge(df, how='left')
    .rename(columns={'organization_name': 'school_dist'})
    .drop(columns=['category', 'school_year', 'org_code'])
    .drop_duplicates()
)
df.insert(0, 'county', df.pop('county_name'))
df.to_csv('../working-data/dist_mobility_rate.csv', index=False)
df
# Out:
#           county                 school_dist  total_pupil_count_all_students  \
# 0    STATE TOTAL                 STATE TOTAL                        939283.0
# 1          ADAMS                  MAPLETON 1                          9037.0
# 2          ADAMS  ADAMS 12 FIVE STAR SCHOOLS                         49889.0
# 3          ADAMS             ADAMS COUNTY 14                          8265.0
# 4          ADAMS                BRIGHTON 27J                         17152.0
# ..           ...                         ...                             ...
# 179       DENVER    CHARTER SCHOOL INSTITUTE                         12020.0
# 180      CHAFFEE              MOUNTAIN BOCES                           184.0
# 181         WELD            CENTENNIAL BOCES                           146.0
# 182     LA PLATA              SAN JUAN BOCES                            84.0
# 183       DENVER         EXPEDITIONARY BOCES                           402.0
#
#      total_stable_pupil_count_all_students  total_stability_rate_all_students  \
# 0                                 705064.0                               75.1
# 1                                   5077.0                               56.2
# 2                                  34283.0                               68.7
# 3                                   5510.0                               66.7
# 4                                  13109.0                               76.4
# ..                                     ...                                ...
# 179                                 5323.0                               44.3
# 180                                   76.0                               41.3
# 181                                    0.0                                0.0
# 182                                    0.0                                0.0
# 183                                  302.0                               75.1
#
#      total_mobile_student_count_all_students  \
# 0                                   231706.0
# 1                                     3919.0
# 2                                    15424.0
# 3                                     3038.0
# 4                                     3982.0
# ..                                       ...
# 179                                   6660.0
# 180                                    113.0
# 181                                    146.0
# 182                                     84.0
# 183                                    100.0
#
#      total_student_mobility_rate_all_students  \
# 0                                        24.7
# 1                                        43.4
# 2                                        30.9
# 3                                        36.8
# 4                                        23.2
# ..                                        ...
# 179                                      55.4
# 180                                      61.4
# 181                                     100.0
# 182                                     100.0
# 183                                      24.9
#
#      total_instances_of_mobility_all_students  \
# 0                                    253577.0
# 1                                      4133.0
# 2                                     16854.0
# 3                                      3397.0
# 4                                      4294.0
# ..                                        ...
# 179                                    6800.0
# 180                                     116.0
# 181                                     146.0
# 182                                      84.0
# 183                                     101.0
#
#      total_mobility_incidence_rate_all_students  \
# 0                                          27.0
# 1                                          45.7
# 2                                          33.8
# 3                                          41.1
# 4                                          25.0
# ..                                          ...
# 179                                        56.6
# 180                                        63.0
# 181                                       100.0
# 182                                       100.0
# 183                                        25.1
#
#      students_with_disabilities_pupil_count  ...  \
# 0                                   84121.0  ...
# 1                                     735.0  ...
# 2                                    4339.0  ...
# 3                                     876.0  ...
# 4                                    1405.0  ...
# ..                                      ...  ...
# 179                                   708.0  ...
# 180                                    36.0  ...
# 181                                     2.0  ...
# 182                                     5.0  ...
# 183                                    40.0  ...
#
#      homeless_student_mobility_rate  homeless_instances_of_mobility  \
# 0                              45.3                         11558.0
# 1                              32.7                            79.0
# 2                              57.2                           481.0
# 3                              49.7                           529.0
# 4                              67.9                           287.0
# ..                              ...                             ...
# 179                            72.3                            69.0
# 180                            57.1                            21.0
# 181                             0.0                             0.0
# 182                             0.0                             0.0
# 183                             0.0                             0.0
#
#      homeless_mobility_incidence_rate  gifted_talented_pupil_count  \
# 0                                54.2                      73344.0
# 1                                36.9                        250.0
# 2                                68.2                       3590.0
# 3                                59.7                        377.0
# 4                                74.9                        703.0
# ..                                ...                          ...
# 179                              73.4                        343.0
# 180                              60.0                          1.0
# 181                               0.0                          0.0
# 182                               0.0                          3.0
# 183                               0.0                          0.0
#
#      gifted_talented_stable_student_count  gifted_talented_stability_rate  \
# 0                                 66620.0                            90.8
# 1                                   205.0                            82.0
# 2                                  3225.0                            89.8
# 3                                   317.0                            84.1
# 4                                   630.0                            89.6
# ..                                    ...                             ...
# 179                                 172.0                            50.1
# 180                                   1.0                           100.0
# 181                                   0.0                             0.0
# 182                                   0.0                             0.0
# 183                                   0.0                             0.0
#
#      gifted_talented_mobile_student_count  \
# 0                                  6641.0
# 1                                    44.0
# 2                                   361.0
# 3                                    75.0
# 4                                    70.0
# ..                                    ...
# 179                                 169.0
# 180                                   0.0
# 181                                   0.0
# 182                                   3.0
# 183                                   0.0
#
#      gifted_talented_student_mobility_rate  \
# 0                                      9.1
# 1                                     17.6
# 2                                     10.1
# 3                                     19.9
# 4                                     10.0
# ..                                     ...
# 179                                   49.3
# 180                                    0.0
# 181                                    0.0
# 182                                  100.0
# 183                                    0.0
#
#      gifted_talented_instances_of_mobility  \
# 0                                   7366.0
# 1                                     47.0
# 2                                    404.0
# 3                                     89.0
# 4                                     76.0
# ..                                     ...
# 179                                  174.0
# 180                                    1.0
# 181                                    0.0
# 182                                    3.0
# 183                                    0.0
#
#      gifted_talented_mobility_incidence_rate
# 0                                       10.0
# 1                                       18.8
# 2                                       11.3
# 3                                       23.6
# 4                                       10.8
# ..                                       ...
# 179                                     50.7
# 180                                    100.0
# 181                                      0.0
# 182                                    100.0
# 183                                      0.0
#
# [184 rows x 58 columns]

# %%
df = df_mobility_demo.copy()
df = (county
    .merge(df, how='left')
    .rename(columns={'organization_name': 'school_dist'})
    .drop(columns=['category', 'school_year', 'org_code'])
    .drop_duplicates()
)
df.insert(0, 'county', df.pop('county_name'))
df.to_csv('../working-data/dist_mobility_rate_demographics.csv', index=False)
df
# Out:
#           county                 school_dist  total_pupil_count  \
# 0    STATE TOTAL                 STATE TOTAL           939283.0
# 2          ADAMS                  MAPLETON 1             9037.0
# 3          ADAMS  ADAMS 12 FIVE STAR SCHOOLS            49889.0
# 4          ADAMS             ADAMS COUNTY 14             8265.0
# 5          ADAMS                BRIGHTON 27J            17152.0
# ..           ...                         ...                ...
# 180       DENVER    CHARTER SCHOOL INSTITUTE            12020.0
# 181      CHAFFEE              MOUNTAIN BOCES              184.0
# 182         WELD            CENTENNIAL BOCES              146.0
# 183     LA PLATA              SAN JUAN BOCES               84.0
# 184       DENVER         EXPEDITIONARY BOCES              402.0
#
#      total_stable_student_count  total_stability_rate  \
# 0                      705064.0                  75.1
# 2                        5077.0                  56.2
# 3                       34283.0                  68.7
# 4                        5510.0                  66.7
# 5                       13109.0                  76.4
# ..                          ...                   ...
# 180                      5323.0                  44.3
# 181                        76.0                  41.3
# 182                         0.0                   0.0
# 183                         0.0                   0.0
# 184                       302.0                  75.1
#
#      total_mobile_student_count  total_student_mobility_rate  \
# 0                      231706.0                         24.7
# 2                        3919.0                         43.4
# 3                       15424.0                         30.9
# 4                        3038.0                         36.8
# 5                        3982.0                         23.2
# ..                          ...                          ...
# 180                      6660.0                         55.4
# 181                       113.0                         61.4
# 182                       146.0                        100.0
# 183                        84.0                        100.0
# 184                       100.0                         24.9
#
#      total_instances_of_mobility  total_mobility_incidence_rate  \
# 0                       253577.0                           27.0
# 2                         4133.0                           45.7
# 3                        16854.0                           33.8
# 4                         3397.0                           41.1
# 5                         4294.0                           25.0
# ..                           ...                            ...
# 180                       6800.0                           56.6
# 181                        116.0                           63.0
# 182                        146.0                          100.0
# 183                         84.0                          100.0
# 184                        101.0                           25.1
#
#      total_female_pupil_count  ...  \
# 0                    458512.0  ...
# 2                      4450.0  ...
# 3                     24340.0  ...
# 4                      3966.0  ...
# 5                      8452.0  ...
# ..                        ...  ...
# 180                    6311.0  ...
# 181                     103.0  ...
# 182                      64.0  ...
# 183                      36.0  ...
# 184                     184.0  ...
#
#      total_native_hawaiian_or_other_pacific_islander_student_mobility_rate  \
# 0                                                 34.8
# 2                                                 70.8
# 3                                                 45.3
# 4                                                  0.0
# 5                                                 30.6
# ..                                                 ...
# 180                                               51.9
# 181                                                0.0
# 182                                                0.0
# 183                                                0.0
# 184                                                0.0
#
#      total_native_hawaiian_or_other_pacific_islander_instances_of_mobility  \
# 0                                                840.0
# 2                                                 17.0
# 3                                                 42.0
# 4                                                  0.0
# 5                                                 12.0
# ..                                                 ...
# 180                                               15.0
# 181                                                0.0
# 182                                                0.0
# 183                                                0.0
# 184                                                0.0
#
#      total_native_hawaiian_or_other_pacific_islander_mobility_incidence_rate  \
# 0                                                 38.0
# 2                                                 70.8
# 3                                                 48.8
# 4                                                  0.0
# 5                                                 33.3
# ..                                                 ...
# 180                                               55.6
# 181                                                0.0
# 182                                                0.0
# 183                                                0.0
# 184                                                0.0
#
#      total_two_or_more_races_pupil_count  \
# 0                                29329.0
# 2                                  219.0
# 3                                  662.0
# 4                                   55.0
# 5                                  423.0
# ..                                   ...
# 180                                187.0
# 181                                  0.0
# 182                                  0.0
# 183                                  3.0
# 184                                 26.0
#
#      total_two_or_more_races_stable_student_count  \
# 0                                         21501.0
# 2                                           129.0
# 3                                           455.0
# 4                                            28.0
# 5                                           304.0
# ..                                            ...
# 180                                          92.0
# 181                                           0.0
# 182                                           0.0
# 183                                           0.0
# 184                                          16.0
#
#      total_two_or_more_races_stability_rate  \
# 0                                      73.3
# 2                                      58.9
# 3                                      68.7
# 4                                      50.9
# 5                                      71.9
# ..                                      ...
# 180                                    49.2
# 181                                     0.0
# 182                                     0.0
# 183                                     0.0
# 184                                    61.5
#
#      total_two_or_more_races_mobile_student_count  \
# 0                                          7718.0
# 2                                            90.0
# 3                                           203.0
# 4                                            26.0
# 5                                           117.0
# ..                                            ...
# 180                                          94.0
# 181                                           0.0
# 182                                           0.0
# 183                                           3.0
# 184                                          10.0
#
#      total_two_or_more_races_student_mobility_rate  \
# 0                                             26.3
# 2                                             41.1
# 3                                             30.7
# 4                                             47.3
# 5                                             27.7
# ..                                             ...
# 180                                           50.3
# 181                                            0.0
# 182                                            0.0
# 183                                          100.0
# 184                                           38.5
#
#      total_two_or_more_races_instances_of_mobility  \
# 0                                           8433.0
# 2                                             91.0
# 3                                            222.0
# 4                                             28.0
# 5                                            127.0
# ..                                             ...
# 180                                           96.0
# 181                                            0.0
# 182                                            0.0
# 183                                            3.0
# 184                                           10.0
#
#      total_two_or_more_races_mobility_incidence_rate
# 0                                               28.8
# 2                                               41.6
# 3                                               33.5
# 4                                               50.9
# 5                                               30.0
# ..                                               ...
# 180                                             51.3
# 181                                              0.0
# 182                                              0.0
# 183                                            100.0
# 184                                             38.5
#
# [184 rows x 72 columns]

# %%
df = df_grad_rate.copy()
df = df.drop(columns='county_name')
df = (county
    .merge(df, how='left')
    .rename(columns={'organization_name': 'school_dist'})
    .drop(columns=['organization_code'])
    .drop_duplicates()
)
df.insert(0, 'county', df.pop('county_name'))
df.to_csv('../working-data/dist_grad_rate.csv', index=False)
df
# Out:
#           county                 school_dist  \
# 0    STATE TOTAL                 STATE TOTAL
# 2          ADAMS                  MAPLETON 1
# 3          ADAMS  ADAMS 12 FIVE STAR SCHOOLS
# 4          ADAMS             ADAMS COUNTY 14
# 5          ADAMS                BRIGHTON 27J
# ..           ...                         ...
# 180       DENVER    CHARTER SCHOOL INSTITUTE
# 181      CHAFFEE              MOUNTAIN BOCES
# 182         WELD            CENTENNIAL BOCES
# 183     LA PLATA              SAN JUAN BOCES
# 184       DENVER         EXPEDITIONARY BOCES
#
#      students_with_disabilities_final_grad_base  \
# 0                                        5775.0
# 2                                          49.0
# 3                                         250.0
# 4                                          59.0
# 5                                          66.0
# ..                                          ...
# 180                                       111.0
# 181                                        19.0
# 182                                         6.0
# 183                                         1.0
# 184                                         2.0
#
#      students_with_disabilities_graduates_total  \
# 0                                        3099.0
# 2                                          18.0
# 3                                         118.0
# 4                                          32.0
# 5                                          33.0
# ..                                          ...
# 180                                        16.0
# 181                                        14.0
# 182                                         1.0
# 183                                         0.0
# 184                                         2.0
#
#      students_with_disabilities_graduation_rate  \
# 0                                          53.7
# 2                                          36.7
# 3                                          47.2
# 4                                          54.2
# 5                                          50.0
# ..                                          ...
# 180                                        14.4
# 181                                        73.7
# 182                                        16.7
# 183                                         0.0
# 184                                       100.0
#
#      students_with_disabilities_completers_total  \
# 0                                         3222.0
# 2                                           19.0
# 3                                          127.0
# 4                                           32.0
# 5                                           35.0
# ..                                           ...
# 180                                         17.0
# 181                                         16.0
# 182                                          1.0
# 183                                          0.0
# 184                                          2.0
#
#      students_with_disabilities_completion_rate  \
# 0                                          55.8
# 2                                          38.8
# 3                                          50.8
# 4                                          54.2
# 5                                          53.0
# ..                                          ...
# 180                                        15.3
# 181                                        84.2
# 182                                        16.7
# 183                                         0.0
# 184                                       100.0
#
#      limited_english_proficient_final_grad_base  \
# 0                                        6171.0
# 2                                         219.0
# 3                                         379.0
# 4                                         170.0
# 5                                         110.0
# ..                                          ...
# 180                                       141.0
# 181                                        17.0
# 182                                         4.0
# 183                                         1.0
# 184                                         0.0
#
#      limited_english_proficient_graduates_total  \
# 0                                        3289.0
# 2                                          73.0
# 3                                         257.0
# 4                                          86.0
# 5                                          63.0
# ..                                          ...
# 180                                        31.0
# 181                                        10.0
# 182                                         1.0
# 183                                         1.0
# 184                                         0.0
#
#      limited_english_proficient_graduation_rate  ...  \
# 0                                          53.3  ...
# 2                                          33.3  ...
# 3                                          67.8  ...
# 4                                          50.6  ...
# 5                                          57.3  ...
# ..                                          ...  ...
# 180                                        22.0  ...
# 181                                        58.8  ...
# 182                                        25.0  ...
# 183                                       100.0  ...
# 184                                         0.0  ...
#
#      homeless_final_grad_base  homeless_graduates_total  \
# 0                      2394.0                    1175.0
# 2                        41.0                      12.0
# 3                       106.0                      62.0
# 4                        99.0                      52.0
# 5                        41.0                      21.0
# ..                        ...                       ...
# 180                     121.0                      11.0
# 181                      14.0                       9.0
# 182                       1.0                       0.0
# 183                       0.0                       0.0
# 184                       0.0                       0.0
#
#      homeless_graduation_rate  homeless_completers_total  \
# 0                        49.1                     1262.0
# 2                        29.3                       16.0
# 3                        58.5                       65.0
# 4                        52.5                       57.0
# 5                        51.2                       21.0
# ..                        ...                        ...
# 180                       9.1                       11.0
# 181                      64.3                       10.0
# 182                       0.0                        0.0
# 183                       0.0                        0.0
# 184                       0.0                        0.0
#
#      homeless_completion_rate  gifted_talented_final_grad_base  \
# 0                        52.7                           6604.0
# 2                        39.0                             44.0
# 3                        61.3                            227.0
# 4                        57.6                             30.0
# 5                        51.2                             63.0
# ..                        ...                              ...
# 180                       9.1                             47.0
# 181                      71.4                              2.0
# 182                       0.0                              0.0
# 183                       0.0                              1.0
# 184                       0.0                              0.0
#
#      gifted_talented_graduates_total  gifted_talented_graduation_rate  \
# 0                             6048.0                             91.6
# 2                               27.0                             61.4
# 3                              201.0                             88.5
# 4                               27.0                             90.0
# 5                               51.0                             81.0
# ..                               ...                              ...
# 180                             23.0                             48.9
# 181                              1.0                             50.0
# 182                              0.0                              0.0
# 183                              0.0                              0.0
# 184                              0.0                              0.0
#
#      gifted_talented_completers_total  gifted_talented_completion_rate
# 0                              6156.0                             93.2
# 2                                27.0                             61.4
# 3                               208.0                             91.6
# 4                                27.0                             90.0
# 5                                52.0                             82.5
# ..                                ...                              ...
# 180                              27.0                             57.4
# 181                               1.0                             50.0
# 182                               0.0                              0.0
# 183                               1.0                            100.0
# 184                               0.0                              0.0
#
# [184 rows x 37 columns]
